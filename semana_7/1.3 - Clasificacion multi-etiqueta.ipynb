# %% [markdown]
# # 1.3 - Clasificacion multi-etiqueta
#
# ![mlr](images/mlr.png)
#
#
# ![telecom](images/telecom.jpeg)

# %% [markdown]
# ### Datos

# %% [markdown]
# ### Transformacion

# %% [markdown]
# ### Modelado
