# %%
# asi se comprobaria en OTRO jupyter porque no puedo apagar el servidor

import requests as req

res=req.get('http://127.0.0.1:5020/selec/?c1=user_rating&c2=user_rating_ver').json()

res
# Out:
# {'user_rating': {'0': 4.0,
#   '1': 4.0,
#   '2': 3.5,
#   '3': 4.0,
#   '4': 4.5,
#   '5': 4.0,
#   '6': 4.0,
#   '7': 4.0,
#   '8': 4.5,
#   '9': 4.0,
#   '10': 4.5,
#   '11': 3.5,
#   '12': 3.5,
#   '13': 3.5,
#   '14': 4.5,
#   '15': 4.0,
#   '16': 3.5,
#   '17': 4.0,
#   '18': 4.0,
#   '19': 4.0,
#   '20': 4.5,
#   '21': 5.0,
#   '22': 4.0,
#   '23': 4.5,
#   '24': 4.0,
#   '25': 3.5,
#   '26': 3.0,
#   '27': 3.5,
#   '28': 4.0,
#   '29': 4.0,
#   '30': 3.5,
#   '31': 4.5,
#   '32': 3.0,
#   '33': 3.5,
#   '34': 4.0,
#   '35': 4.0,
#   '36': 3.5,
#   '37': 4.0,
#   '38': 4.5,
#   '39': 4.0,
#   '40': 4.5,
#   '41': 3.0,
#   '42': 3.5,
#   '43': 4.5,
#   '44': 3.0,
#   '45': 3.5,
#   '46': 3.0,
#   '47': 3.0,
#   '48': 3.0,
#   '49': 4.0,
#   '50': 4.0,
#   '51': 3.0,
#   '52': 4.5,
#   '53': 3.5,
#   '54': 3.0,
#   '55': 3.5,
#   '56': 4.5,
#   '57': 4.0,
#   '58': 4.0,
#   '59': 4.0,
#   '60': 3.0,
#   '61': 3.5,
#   '62': 3.5,
#   '63': 4.0,
#   '64': 3.0,
#   '65': 4.5,
# ...
