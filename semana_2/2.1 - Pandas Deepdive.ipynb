# %% [markdown]
# # 2.1 - Pandas Deepdive
#
# ![pandas_deep](images/pandas_deep.jpg)

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### Importar un archivo

# %%
# desde un zip

import zipfile

zf=zipfile.ZipFile('../data/mahindra.zip')

ctr = pd.read_csv(zf.open('test.csv'), nrows=1e4)

ctr.head()
# Out:
#                                       reservation_id booking_date  \
# 0  7dae1ce6bc8f69481328f2be5c4943077dad5598b5f66d...     05/04/18
# 1  fe0d4e444e1818436c88f72f1cf800536c2f785e59baeb...     24/05/15
# 2  540bd4285ad8168e8388f84ee74a82cd4f97dc0a404d3e...     21/07/15
# 3  09593c907ae262e46f655b4db9e14f54a19eadcfdd2679...     31/07/15
# 4  f4c50caac68051faf37551d70bb17eebef2a20e2244cb1...     01/07/16
#
#   checkin_date checkout_date  channel_code  main_product_code  numberofadults  \
# 0     05/04/18      06/04/18             3                  2               2
# 1     23/06/15      27/06/15             1                  2               4
# 2     07/08/15      10/08/15             3                  2               3
# 3     22/10/15      25/10/15             1                  2               3
# 4     01/10/16      05/10/16             1                  2               4
#
#    numberofchildren  persontravellingid  resort_region_code  ...  \
# 0                 0                  45                   3  ...
# 1                 0                  45                   1  ...
# 2                 0                  45                   2  ...
# 3                 0                  45                   1  ...
# 4                 0                  45                   1  ...
#
#    season_holidayed_code  state_code_residence  state_code_resort  total_pax  \
# 0                    2.0                   2.0                  3          3
# 1                    2.0                   2.0                  4          2
# 2                    4.0                   2.0                  2          3
# 3                    2.0                   2.0                  6          3
# 4                    2.0                   2.0                 11          2
#
#    member_age_buckets  booking_type_code  \
# 0                   H                  1
# 1                   H                  1
# 2                   H                  1
# 3                   H                  1
# 4                   H                  1
#
#                                             memberid cluster_code  \
# 0  2114944930dcc42ce5b9b50ae965cf8a9c04e46be63d84...            A
# 1  2114944930dcc42ce5b9b50ae965cf8a9c04e46be63d84...            F
# 2  2114944930dcc42ce5b9b50ae965cf8a9c04e46be63d84...            D
# 3  2114944930dcc42ce5b9b50ae965cf8a9c04e46be63d84...            F
# 4  2114944930dcc42ce5b9b50ae965cf8a9c04e46be63d84...            F
#
#    reservationstatusid_code                                          resort_id
# 0                         C  9f14025af0065b30e47e23ebb3b491d39ae8ed17d33739...
# 1                         A  e7f6c011776e8db7cd330b54174fd76f7d0216b612387a...
# 2                         A  d4735e3a265e16eee03f59718b9b5d03019c07d8b6c51f...
# 3                         A  49d180ecf56132819571bf39d9b7b342522a2ac6d23c14...
# 4                         A  e29c9c180c6279b0b02abd6a1801c7c04082cf486ec027...
#
# [5 rows x 23 columns]

# %%
df = pd.read_excel('../data/Online Retail.xlsx')

df.head()
# Out:
#    InvoiceNo         InvoiceDate StockCode  \
# 0     536365 2010-12-01 08:26:00    85123A
# 1     536373 2010-12-01 09:02:00    85123A
# 2     536375 2010-12-01 09:32:00    85123A
# 3     536390 2010-12-01 10:19:00    85123A
# 4     536394 2010-12-01 10:39:00    85123A
#
#                           Description  Quantity  UnitPrice  Revenue  \
# 0  CREAM HANGING HEART T-LIGHT HOLDER         6       2.55     15.3
# 1  CREAM HANGING HEART T-LIGHT HOLDER         6       2.55     15.3
# 2  CREAM HANGING HEART T-LIGHT HOLDER         6       2.55     15.3
# 3  CREAM HANGING HEART T-LIGHT HOLDER        64       2.55    163.2
# 4  CREAM HANGING HEART T-LIGHT HOLDER        32       2.55     81.6
#
#    CustomerID         Country
# 0       17850  United Kingdom
# 1       17850  United Kingdom
# 2       17850  United Kingdom
# 3       17511  United Kingdom
# 4       13408  United Kingdom

# %%
df.shape
# Out:
# (396034, 9)

# %%
df.shape[0], len(df)
# Out:
# (396034, 396034)

# %%
# crear una columna con nulos

df['Null ID'] = [i if i%2 else None for i in range(len(df))]

df.head()
# Out:
#    InvoiceNo         InvoiceDate StockCode  \
# 0     536365 2010-12-01 08:26:00    85123A
# 1     536373 2010-12-01 09:02:00    85123A
# 2     536375 2010-12-01 09:32:00    85123A
# 3     536390 2010-12-01 10:19:00    85123A
# 4     536394 2010-12-01 10:39:00    85123A
#
#                           Description  Quantity  UnitPrice  Revenue  \
# 0  CREAM HANGING HEART T-LIGHT HOLDER         6       2.55     15.3
# 1  CREAM HANGING HEART T-LIGHT HOLDER         6       2.55     15.3
# 2  CREAM HANGING HEART T-LIGHT HOLDER         6       2.55     15.3
# 3  CREAM HANGING HEART T-LIGHT HOLDER        64       2.55    163.2
# 4  CREAM HANGING HEART T-LIGHT HOLDER        32       2.55     81.6
#
#    CustomerID         Country  Null ID
# 0       17850  United Kingdom      NaN
# 1       17850  United Kingdom      1.0
# 2       17850  United Kingdom      NaN
# 3       17511  United Kingdom      3.0
# 4       13408  United Kingdom      NaN

# %%
df.columns
# Out:
# Index(['InvoiceNo', 'InvoiceDate', 'StockCode', 'Description', 'Quantity',
#        'UnitPrice', 'Revenue', 'CustomerID', 'Country', 'Null ID'],
#       dtype='object')

# %%
# equivalente [e.lower().replace(' ', '') for e in df.columns]


lst = []

for columna in df.columns:
    
    columna=columna.lower().replace(' ', '')
    
    lst.append(columna)
    
lst
# Out:
# ['invoiceno',
#  'invoicedate',
#  'stockcode',
#  'description',
#  'quantity',
#  'unitprice',
#  'revenue',
#  'customerid',
#  'country',
#  'nullid']

# %%
# asi las cambio todas

df.columns = [e.lower().replace(' ', '') for e in df.columns]

df.head()
# Out:
#    invoiceno         invoicedate stockcode  \
# 0     536365 2010-12-01 08:26:00    85123A
# 1     536373 2010-12-01 09:02:00    85123A
# 2     536375 2010-12-01 09:32:00    85123A
# 3     536390 2010-12-01 10:19:00    85123A
# 4     536394 2010-12-01 10:39:00    85123A
#
#                           description  quantity  unitprice  revenue  \
# 0  CREAM HANGING HEART T-LIGHT HOLDER         6       2.55     15.3
# 1  CREAM HANGING HEART T-LIGHT HOLDER         6       2.55     15.3
# 2  CREAM HANGING HEART T-LIGHT HOLDER         6       2.55     15.3
# 3  CREAM HANGING HEART T-LIGHT HOLDER        64       2.55    163.2
# 4  CREAM HANGING HEART T-LIGHT HOLDER        32       2.55     81.6
#
#    customerid         country  nullid
# 0       17850  United Kingdom     NaN
# 1       17850  United Kingdom     1.0
# 2       17850  United Kingdom     NaN
# 3       17511  United Kingdom     3.0
# 4       13408  United Kingdom     NaN

# %%
df.country[:5]
# Out:
# 0    United Kingdom
# 1    United Kingdom
# 2    United Kingdom
# 3    United Kingdom
# 4    United Kingdom
# Name: country, dtype: object

# %%
n_cols = [e.upper().replace(' ', '') for e in df.columns]

# %%
{k:v for k,v in zip(df.columns, n_cols)}
# Out:
# {'invoiceno': 'INVOICENO',
#  'invoicedate': 'INVOICEDATE',
#  'stockcode': 'STOCKCODE',
#  'description': 'DESCRIPTION',
#  'quantity': 'QUANTITY',
#  'unitprice': 'UNITPRICE',
#  'revenue': 'REVENUE',
#  'customerid': 'CUSTOMERID',
#  'country': 'COUNTRY',
#  'nullid': 'NULLID'}

# %%
# k=vieja columna, v=nueva columna, todas o algunas

df=df.rename(columns={k:v for k,v in zip(df.columns, n_cols)})  # todas

df.head()
# Out:
#    INVOICENO         INVOICEDATE STOCKCODE  \
# 0     536365 2010-12-01 08:26:00    85123A
# 1     536373 2010-12-01 09:02:00    85123A
# 2     536375 2010-12-01 09:32:00    85123A
# 3     536390 2010-12-01 10:19:00    85123A
# 4     536394 2010-12-01 10:39:00    85123A
#
#                           DESCRIPTION  QUANTITY  UNITPRICE  REVENUE  \
# 0  CREAM HANGING HEART T-LIGHT HOLDER         6       2.55     15.3
# 1  CREAM HANGING HEART T-LIGHT HOLDER         6       2.55     15.3
# 2  CREAM HANGING HEART T-LIGHT HOLDER         6       2.55     15.3
# 3  CREAM HANGING HEART T-LIGHT HOLDER        64       2.55    163.2
# 4  CREAM HANGING HEART T-LIGHT HOLDER        32       2.55     81.6
#
#    CUSTOMERID         COUNTRY  NULLID
# 0       17850  United Kingdom     NaN
# 1       17850  United Kingdom     1.0
# 2       17850  United Kingdom     NaN
# 3       17511  United Kingdom     3.0
# 4       13408  United Kingdom     NaN

# %%
df.columns = [e.lower().replace(' ', '') for e in df.columns]

df.head()
# Out:
#    invoiceno         invoicedate stockcode  \
# 0     536365 2010-12-01 08:26:00    85123A
# 1     536373 2010-12-01 09:02:00    85123A
# 2     536375 2010-12-01 09:32:00    85123A
# 3     536390 2010-12-01 10:19:00    85123A
# 4     536394 2010-12-01 10:39:00    85123A
#
#                           description  quantity  unitprice  revenue  \
# 0  CREAM HANGING HEART T-LIGHT HOLDER         6       2.55     15.3
# 1  CREAM HANGING HEART T-LIGHT HOLDER         6       2.55     15.3
# 2  CREAM HANGING HEART T-LIGHT HOLDER         6       2.55     15.3
# 3  CREAM HANGING HEART T-LIGHT HOLDER        64       2.55    163.2
# 4  CREAM HANGING HEART T-LIGHT HOLDER        32       2.55     81.6
#
#    customerid         country  nullid
# 0       17850  United Kingdom     NaN
# 1       17850  United Kingdom     1.0
# 2       17850  United Kingdom     NaN
# 3       17511  United Kingdom     3.0
# 4       13408  United Kingdom     NaN

# %%
df=df.rename(columns={'nullid': 'null'})  # solo una

df.head()
# Out:
#    invoiceno         invoicedate stockcode  \
# 0     536365 2010-12-01 08:26:00    85123A
# 1     536373 2010-12-01 09:02:00    85123A
# 2     536375 2010-12-01 09:32:00    85123A
# 3     536390 2010-12-01 10:19:00    85123A
# 4     536394 2010-12-01 10:39:00    85123A
#
#                           description  quantity  unitprice  revenue  \
# 0  CREAM HANGING HEART T-LIGHT HOLDER         6       2.55     15.3
# 1  CREAM HANGING HEART T-LIGHT HOLDER         6       2.55     15.3
# 2  CREAM HANGING HEART T-LIGHT HOLDER         6       2.55     15.3
# 3  CREAM HANGING HEART T-LIGHT HOLDER        64       2.55    163.2
# 4  CREAM HANGING HEART T-LIGHT HOLDER        32       2.55     81.6
#
#    customerid         country  null
# 0       17850  United Kingdom   NaN
# 1       17850  United Kingdom   1.0
# 2       17850  United Kingdom   NaN
# 3       17511  United Kingdom   3.0
# 4       13408  United Kingdom   NaN

# %%
df=df.rename(columns={'null': 0})  # solo una

df.head()
# Out:
#    invoiceno         invoicedate stockcode  \
# 0     536365 2010-12-01 08:26:00    85123A
# 1     536373 2010-12-01 09:02:00    85123A
# 2     536375 2010-12-01 09:32:00    85123A
# 3     536390 2010-12-01 10:19:00    85123A
# 4     536394 2010-12-01 10:39:00    85123A
#
#                           description  quantity  unitprice  revenue  \
# 0  CREAM HANGING HEART T-LIGHT HOLDER         6       2.55     15.3
# 1  CREAM HANGING HEART T-LIGHT HOLDER         6       2.55     15.3
# 2  CREAM HANGING HEART T-LIGHT HOLDER         6       2.55     15.3
# 3  CREAM HANGING HEART T-LIGHT HOLDER        64       2.55    163.2
# 4  CREAM HANGING HEART T-LIGHT HOLDER        32       2.55     81.6
#
#    customerid         country    0
# 0       17850  United Kingdom  NaN
# 1       17850  United Kingdom  1.0
# 2       17850  United Kingdom  NaN
# 3       17511  United Kingdom  3.0
# 4       13408  United Kingdom  NaN

# %%
type(df.columns[-1])
# Out:
# int

# %%
df=df.rename(columns={0: 'null'})  # solo una

df.head()
# Out:
#    invoiceno         invoicedate stockcode  \
# 0     536365 2010-12-01 08:26:00    85123A
# 1     536373 2010-12-01 09:02:00    85123A
# 2     536375 2010-12-01 09:32:00    85123A
# 3     536390 2010-12-01 10:19:00    85123A
# 4     536394 2010-12-01 10:39:00    85123A
#
#                           description  quantity  unitprice  revenue  \
# 0  CREAM HANGING HEART T-LIGHT HOLDER         6       2.55     15.3
# 1  CREAM HANGING HEART T-LIGHT HOLDER         6       2.55     15.3
# 2  CREAM HANGING HEART T-LIGHT HOLDER         6       2.55     15.3
# 3  CREAM HANGING HEART T-LIGHT HOLDER        64       2.55    163.2
# 4  CREAM HANGING HEART T-LIGHT HOLDER        32       2.55     81.6
#
#    customerid         country  null
# 0       17850  United Kingdom   NaN
# 1       17850  United Kingdom   1.0
# 2       17850  United Kingdom   NaN
# 3       17511  United Kingdom   3.0
# 4       13408  United Kingdom   NaN

# %% [markdown]
# ### Descripción de los datos

# %%
df.shape
# Out:
# (396034, 10)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 396034 entries, 0 to 396033
# Data columns (total 10 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   invoiceno    396034 non-null  int64
#  1   invoicedate  396034 non-null  datetime64[ns]
#  2   stockcode    396034 non-null  object
#  3   description  396034 non-null  object
#  4   quantity     396034 non-null  int64
#  5   unitprice    396034 non-null  float64
#  6   revenue      396034 non-null  float64
#  7   customerid   396034 non-null  int64
#  8   country      396034 non-null  object
#  9   null         198017 non-null  float64
# dtypes: datetime64[ns](1), float64(3), int64(3), object(3)
# memory usage: 30.2+ MB

# %%
df.info(memory_usage='deep')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 396034 entries, 0 to 396033
# Data columns (total 10 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   invoiceno    396034 non-null  int64
#  1   invoicedate  396034 non-null  datetime64[ns]
#  2   stockcode    396034 non-null  object
#  3   description  396034 non-null  object
#  4   quantity     396034 non-null  int64
#  5   unitprice    396034 non-null  float64
#  6   revenue      396034 non-null  float64
#  7   customerid   396034 non-null  int64
#  8   country      396034 non-null  object
#  9   null         198017 non-null  float64
# dtypes: datetime64[ns](1), float64(3), int64(3), object(3)
# memory usage: 93.7 MB

# %%
df2=df.copy()   # cuidadin, que son lo mismo si no poneis el .copy()

# %%
df.count()   # valores NO nulos
# Out:
# invoiceno      396034
# invoicedate    396034
# stockcode      396034
# description    396034
# quantity       396034
# unitprice      396034
# revenue        396034
# customerid     396034
# country        396034
# null           198017
# dtype: int64

# %%
df.country.unique()       # df['country'].unique() valores unicos de la columna
# Out:
# array(['United Kingdom', 'Spain', 'Cyprus', 'EIRE', 'Portugal',
#        'Netherlands', 'Australia', 'Singapore', 'Switzerland', 'Finland',
#        'Channel Islands', 'France', 'Malta', 'Italy', 'Israel', 'Germany',
#        'Austria', 'Norway', 'Denmark', 'Sweden', 'Belgium', 'Canada',
#        'Poland', 'Japan', 'Iceland', 'Greece', 'Lebanon', 'South Africa',
#        'Czech Republic', 'USA', 'Brazil', 'United Arab Emirates',
#        'Lithuania', 'Saudi Arabia', 'Bahrain'], dtype=object)

# %%
len(df.country.unique())    # numero de elementos unicos
# Out:
# 35

# %%
df.country.value_counts()    # cuantos hay de cada uno
# Out:
# United Kingdom          353983
# Germany                   8658
# France                    8034
# EIRE                      7136
# Spain                     2422
# Netherlands               2322
# Belgium                   1935
# Switzerland               1810
# Portugal                  1425
# Australia                 1181
# Norway                    1048
# Channel Islands            744
# Italy                      741
# Finland                    647
# Cyprus                     612
# Sweden                     428
# Austria                    384
# Denmark                    367
# Poland                     325
# Japan                      321
# Israel                     248
# Singapore                  215
# Iceland                    182
# USA                        179
# Canada                     150
# Greece                     142
# Malta                      109
# United Arab Emirates        67
# South Africa                57
# Lebanon                     45
# Lithuania                   35
# Brazil                      32
# Czech Republic              24
# Bahrain                     17
# Saudi Arabia                 9
# Name: country, dtype: int64

# %%
df.describe()    # descripcion estadistica
# Out:
#            invoiceno       quantity      unitprice        revenue  \
# count  396034.000000  396034.000000  396034.000000  396034.000000
# mean   560620.294401      12.624838       2.867826      21.492062
# std     13110.655964      42.816911       4.265226      93.863439
# min    536365.000000       1.000000       0.040000       0.060000
# 25%    549198.500000       2.000000       1.250000       4.680000
# 50%    561894.000000       6.000000       1.950000      11.800000
# 75%    572095.000000      12.000000       3.750000      19.800000
# max    581587.000000    4800.000000     649.500000   38970.000000
#
#           customerid           null
# count  396034.000000  198017.000000
# mean    15302.695435  198017.000000
# std      1709.744925  114325.456929
# min     12347.000000       1.000000
# 25%     13975.000000   99009.000000
# 50%     15160.000000  198017.000000
# 75%     16805.000000  297025.000000
# max     18287.000000  396033.000000

# %%
df.describe().T
# Out:
#                count           mean            std        min        25%  \
# invoiceno   396034.0  560620.294401   13110.655964  536365.00  549198.50
# quantity    396034.0      12.624838      42.816911       1.00       2.00
# unitprice   396034.0       2.867826       4.265226       0.04       1.25
# revenue     396034.0      21.492062      93.863439       0.06       4.68
# customerid  396034.0   15302.695435    1709.744925   12347.00   13975.00
# null        198017.0  198017.000000  114325.456929       1.00   99009.00
#
#                   50%        75%       max
# invoiceno   561894.00  572095.00  581587.0
# quantity         6.00      12.00    4800.0
# unitprice        1.95       3.75     649.5
# revenue         11.80      19.80   38970.0
# customerid   15160.00   16805.00   18287.0
# null        198017.00  297025.00  396033.0

# %%
df.describe(include='all').T
# Out:
# /var/folders/95/ms6dwls51ls1jq0t456d3r200000gn/T/ipykernel_83091/377021028.py:1: FutureWarning: Treating datetime data as categorical rather than numeric in `.describe` is deprecated and will be removed in a future version of pandas. Specify `datetime_is_numeric=True` to silence this warning and adopt the future behavior now.
#   df.describe(include='all').T
#                 count unique                                 top    freq  \
# invoiceno    396034.0    NaN                                 NaN     NaN
# invoicedate    396034  17155                 2011-11-14 15:27:00     541
# stockcode      396034   3658                              85123A    2035
# description    396034   3640  CREAM HANGING HEART T-LIGHT HOLDER    2035
# quantity     396034.0    NaN                                 NaN     NaN
# unitprice    396034.0    NaN                                 NaN     NaN
# revenue      396034.0    NaN                                 NaN     NaN
# customerid   396034.0    NaN                                 NaN     NaN
# country        396034     35                      United Kingdom  353983
# null         198017.0    NaN                                 NaN     NaN
#
#                           first                last           mean  \
# invoiceno                   NaT                 NaT  560620.294401
# invoicedate 2010-12-01 08:26:00 2011-12-09 12:50:00            NaN
# stockcode                   NaT                 NaT            NaN
# description                 NaT                 NaT            NaN
# quantity                    NaT                 NaT      12.624838
# unitprice                   NaT                 NaT       2.867826
# revenue                     NaT                 NaT      21.492062
# customerid                  NaT                 NaT   15302.695435
# country                     NaT                 NaT            NaN
# null                        NaT                 NaT       198017.0
#
#                        std       min       25%       50%       75%       max
# invoiceno     13110.655964  536365.0  549198.5  561894.0  572095.0  581587.0
# invoicedate            NaN       NaN       NaN       NaN       NaN       NaN
# stockcode              NaN       NaN       NaN       NaN       NaN       NaN
# description            NaN       NaN       NaN       NaN       NaN       NaN
# quantity         42.816911       1.0       2.0       6.0      12.0    4800.0
# unitprice         4.265226      0.04      1.25      1.95      3.75     649.5
# revenue          93.863439      0.06      4.68      11.8      19.8   38970.0
# customerid     1709.744925   12347.0   13975.0   15160.0   16805.0   18287.0
# country                NaN       NaN       NaN       NaN       NaN       NaN
# null         114325.456929       1.0   99009.0  198017.0  297025.0  396033.0

# %%
df.unitprice.mode()
# Out:
# 0    1.25
# Name: unitprice, dtype: float64

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
df.median()
# Out:
# invoiceno     561894.00
# quantity           6.00
# unitprice          1.95
# revenue           11.80
# customerid     15160.00
# null          198017.00
# dtype: float64

# %%
df[['quantity', 'unitprice', 'revenue']].describe()
# Out:
#             quantity      unitprice        revenue
# count  396034.000000  396034.000000  396034.000000
# mean       12.624838       2.867826      21.492062
# std        42.816911       4.265226      93.863439
# min         1.000000       0.040000       0.060000
# 25%         2.000000       1.250000       4.680000
# 50%         6.000000       1.950000      11.800000
# 75%        12.000000       3.750000      19.800000
# max      4800.000000     649.500000   38970.000000

# %% [markdown]
# ### Selección dentro del dataframe

# %%
df[['quantity', 'unitprice', 'revenue']].head()
# Out:
#    quantity  unitprice  revenue
# 0         6       2.55     15.3
# 1         6       2.55     15.3
# 2         6       2.55     15.3
# 3        64       2.55    163.2
# 4        32       2.55     81.6

# %%
df[df.quantity == 32].head()
# Out:
#     invoiceno         invoicedate stockcode  \
# 4      536394 2010-12-01 10:39:00    85123A
# 10     536542 2010-12-01 14:11:00    85123A
# 30     536795 2010-12-02 15:40:00    85123A
# 51     537210 2010-12-05 15:15:00    85123A
# 59     537393 2010-12-06 13:59:00    85123A
#
#                            description  quantity  unitprice  revenue  \
# 4   CREAM HANGING HEART T-LIGHT HOLDER        32       2.55     81.6
# 10  CREAM HANGING HEART T-LIGHT HOLDER        32       2.95     94.4
# 30  CREAM HANGING HEART T-LIGHT HOLDER        32       2.55     81.6
# 51  CREAM HANGING HEART T-LIGHT HOLDER        32       2.55     81.6
# 59  CREAM HANGING HEART T-LIGHT HOLDER        32       2.55     81.6
#
#     customerid         country  null
# 4        13408  United Kingdom   NaN
# 10       16456  United Kingdom   NaN
# 30       15640  United Kingdom   NaN
# 51       15953  United Kingdom  51.0
# 59       13089  United Kingdom  59.0

# %%
df[df['quantity'] == 32].head()
# Out:
#     invoiceno         invoicedate stockcode  \
# 4      536394 2010-12-01 10:39:00    85123A
# 10     536542 2010-12-01 14:11:00    85123A
# 30     536795 2010-12-02 15:40:00    85123A
# 51     537210 2010-12-05 15:15:00    85123A
# 59     537393 2010-12-06 13:59:00    85123A
#
#                            description  quantity  unitprice  revenue  \
# 4   CREAM HANGING HEART T-LIGHT HOLDER        32       2.55     81.6
# 10  CREAM HANGING HEART T-LIGHT HOLDER        32       2.95     94.4
# 30  CREAM HANGING HEART T-LIGHT HOLDER        32       2.55     81.6
# 51  CREAM HANGING HEART T-LIGHT HOLDER        32       2.55     81.6
# 59  CREAM HANGING HEART T-LIGHT HOLDER        32       2.55     81.6
#
#     customerid         country  null
# 4        13408  United Kingdom   NaN
# 10       16456  United Kingdom   NaN
# 30       15640  United Kingdom   NaN
# 51       15953  United Kingdom  51.0
# 59       13089  United Kingdom  59.0

# %%
df[(df.quantity == 32) & (df.country!='United Kingdom')].head()  # No se puede and ni or
# Out:
#       invoiceno         invoicedate stockcode  \
# 393      543114 2011-02-03 13:26:00    85123A
# 434      544097 2011-02-16 09:56:00    85123A
# 464      544690 2011-02-23 08:48:00    85123A
# 1061     555947 2011-06-08 10:45:00    85123A
# 1223     560360 2011-07-18 11:55:00    85123A
#
#                              description  quantity  unitprice  revenue  \
# 393   CREAM HANGING HEART T-LIGHT HOLDER        32       2.55     81.6
# 434   CREAM HANGING HEART T-LIGHT HOLDER        32       2.55     81.6
# 464   CREAM HANGING HEART T-LIGHT HOLDER        32       2.55     81.6
# 1061  CREAM HANGING HEART T-LIGHT HOLDER        32       2.55     81.6
# 1223  CREAM HANGING HEART T-LIGHT HOLDER        32       2.55     81.6
#
#       customerid    country    null
# 393        14156       EIRE   393.0
# 434        12455     Cyprus     NaN
# 464        14156       EIRE     NaN
# 1061       14911       EIRE  1061.0
# 1223       12744  Singapore  1223.0

# %%
# &=and , |=or

df[(df.quantity == 32) | (df.country!='United Kingdom')].head()
# Out:
#     invoiceno         invoicedate stockcode  \
# 4      536394 2010-12-01 10:39:00    85123A
# 10     536542 2010-12-01 14:11:00    85123A
# 30     536795 2010-12-02 15:40:00    85123A
# 51     537210 2010-12-05 15:15:00    85123A
# 59     537393 2010-12-06 13:59:00    85123A
#
#                            description  quantity  unitprice  revenue  \
# 4   CREAM HANGING HEART T-LIGHT HOLDER        32       2.55     81.6
# 10  CREAM HANGING HEART T-LIGHT HOLDER        32       2.95     94.4
# 30  CREAM HANGING HEART T-LIGHT HOLDER        32       2.55     81.6
# 51  CREAM HANGING HEART T-LIGHT HOLDER        32       2.55     81.6
# 59  CREAM HANGING HEART T-LIGHT HOLDER        32       2.55     81.6
#
#     customerid         country  null
# 4        13408  United Kingdom   NaN
# 10       16456  United Kingdom   NaN
# 30       15640  United Kingdom   NaN
# 51       15953  United Kingdom  51.0
# 59       13089  United Kingdom  59.0

# %%
df[(df.country != 'EIRE') & (df.country!='United Kingdom')].head()
# Out:
#      invoiceno         invoicedate stockcode  \
# 103     538095 2010-12-09 14:55:00    85123A
# 147     538826 2010-12-14 12:58:00    85123A
# 183     539353 2010-12-17 11:30:00    85123A
# 240     540469 2011-01-07 14:04:00    85123A
# 304     541570 2011-01-19 12:34:00    85123A
#
#                             description  quantity  unitprice  revenue  \
# 103  CREAM HANGING HEART T-LIGHT HOLDER         1       2.95     2.95
# 147  CREAM HANGING HEART T-LIGHT HOLDER        64       2.55   163.20
# 183  CREAM HANGING HEART T-LIGHT HOLDER         6       2.95    17.70
# 240  CREAM HANGING HEART T-LIGHT HOLDER         6       2.95    17.70
# 304  CREAM HANGING HEART T-LIGHT HOLDER       256       2.55   652.80
#
#      customerid      country   null
# 103       17097        Spain  103.0
# 147       12370       Cyprus  147.0
# 183       12782     Portugal  183.0
# 240       12484        Spain    NaN
# 304       14646  Netherlands    NaN

# %%
# la virgulilla ~ delante significa != distinto, es el not bitwise

df[(df.quantity == 32) & ~(df.country=='United Kingdom')].head()
# Out:
#       invoiceno         invoicedate stockcode  \
# 393      543114 2011-02-03 13:26:00    85123A
# 434      544097 2011-02-16 09:56:00    85123A
# 464      544690 2011-02-23 08:48:00    85123A
# 1061     555947 2011-06-08 10:45:00    85123A
# 1223     560360 2011-07-18 11:55:00    85123A
#
#                              description  quantity  unitprice  revenue  \
# 393   CREAM HANGING HEART T-LIGHT HOLDER        32       2.55     81.6
# 434   CREAM HANGING HEART T-LIGHT HOLDER        32       2.55     81.6
# 464   CREAM HANGING HEART T-LIGHT HOLDER        32       2.55     81.6
# 1061  CREAM HANGING HEART T-LIGHT HOLDER        32       2.55     81.6
# 1223  CREAM HANGING HEART T-LIGHT HOLDER        32       2.55     81.6
#
#       customerid    country    null
# 393        14156       EIRE   393.0
# 434        12455     Cyprus     NaN
# 464        14156       EIRE     NaN
# 1061       14911       EIRE  1061.0
# 1223       12744  Singapore  1223.0

# %%
df[(df.quantity == 32) & (df.unitprice!=0.29) | (df.country=='EIRE')].head()
# Out:
#     invoiceno         invoicedate stockcode  \
# 4      536394 2010-12-01 10:39:00    85123A
# 10     536542 2010-12-01 14:11:00    85123A
# 30     536795 2010-12-02 15:40:00    85123A
# 51     537210 2010-12-05 15:15:00    85123A
# 59     537393 2010-12-06 13:59:00    85123A
#
#                            description  quantity  unitprice  revenue  \
# 4   CREAM HANGING HEART T-LIGHT HOLDER        32       2.55     81.6
# 10  CREAM HANGING HEART T-LIGHT HOLDER        32       2.95     94.4
# 30  CREAM HANGING HEART T-LIGHT HOLDER        32       2.55     81.6
# 51  CREAM HANGING HEART T-LIGHT HOLDER        32       2.55     81.6
# 59  CREAM HANGING HEART T-LIGHT HOLDER        32       2.55     81.6
#
#     customerid         country  null
# 4        13408  United Kingdom   NaN
# 10       16456  United Kingdom   NaN
# 30       15640  United Kingdom   NaN
# 51       15953  United Kingdom  51.0
# 59       13089  United Kingdom  59.0

# %%
# seleccion por indices

df.iloc[0]   # primera fila
# Out:
# invoiceno                                  536365
# invoicedate                   2010-12-01 08:26:00
# stockcode                                  85123A
# description    CREAM HANGING HEART T-LIGHT HOLDER
# quantity                                        6
# unitprice                                    2.55
# revenue                                      15.3
# customerid                                  17850
# country                            United Kingdom
# null                                          NaN
# Name: 0, dtype: object

# %%
df.iloc[0:3]
# Out:
#    invoiceno         invoicedate stockcode  \
# 0     536365 2010-12-01 08:26:00    85123A
# 1     536373 2010-12-01 09:02:00    85123A
# 2     536375 2010-12-01 09:32:00    85123A
#
#                           description  quantity  unitprice  revenue  \
# 0  CREAM HANGING HEART T-LIGHT HOLDER         6       2.55     15.3
# 1  CREAM HANGING HEART T-LIGHT HOLDER         6       2.55     15.3
# 2  CREAM HANGING HEART T-LIGHT HOLDER         6       2.55     15.3
#
#    customerid         country  null
# 0       17850  United Kingdom   NaN
# 1       17850  United Kingdom   1.0
# 2       17850  United Kingdom   NaN

# %%
 # df.iloc[fila_inicial: fila_final : step_fila, columna_inicial: columna_final: step_colum] por indice

# %%
df.iloc[0:10:3, 0:5:2]  
# primer slicing por filas, segundo por columnas segun su posicion
# Out:
#    invoiceno stockcode  quantity
# 0     536365    85123A         6
# 3     536390    85123A        64
# 6     536401    85123A         4
# 9     536520    85123A         3

# %%
df.loc[0:5:2, 'country']
# Out:
# 0    United Kingdom
# 2    United Kingdom
# 4    United Kingdom
# Name: country, dtype: object

# %%
df.loc[0:5, 'invoiceno':'stockcode']
# Out:
#    invoiceno         invoicedate stockcode
# 0     536365 2010-12-01 08:26:00    85123A
# 1     536373 2010-12-01 09:02:00    85123A
# 2     536375 2010-12-01 09:32:00    85123A
# 3     536390 2010-12-01 10:19:00    85123A
# 4     536394 2010-12-01 10:39:00    85123A
# 5     536396 2010-12-01 10:51:00    85123A

# %%
df.loc[:3, ['invoiceno', 'invoicedate']]
# Out:
#    invoiceno         invoicedate
# 0     536365 2010-12-01 08:26:00
# 1     536373 2010-12-01 09:02:00
# 2     536375 2010-12-01 09:32:00
# 3     536390 2010-12-01 10:19:00

# %%
df.index
# Out:
# RangeIndex(start=0, stop=396034, step=1)

# %%
df.index = [str(i) for i in range(len(df))]

df.index[:5]
# Out:
# Index(['0', '1', '2', '3', '4'], dtype='object')

# %%
df.iloc[0:5:2]
# Out:
#    invoiceno         invoicedate stockcode  \
# 0     536365 2010-12-01 08:26:00    85123A
# 2     536375 2010-12-01 09:32:00    85123A
# 4     536394 2010-12-01 10:39:00    85123A
#
#                           description  quantity  unitprice  revenue  \
# 0  CREAM HANGING HEART T-LIGHT HOLDER         6       2.55     15.3
# 2  CREAM HANGING HEART T-LIGHT HOLDER         6       2.55     15.3
# 4  CREAM HANGING HEART T-LIGHT HOLDER        32       2.55     81.6
#
#    customerid         country  null
# 0       17850  United Kingdom   NaN
# 2       17850  United Kingdom   NaN
# 4       13408  United Kingdom   NaN

# %%
df.loc['0':'5':2]
# Out:
#    invoiceno         invoicedate stockcode  \
# 0     536365 2010-12-01 08:26:00    85123A
# 2     536375 2010-12-01 09:32:00    85123A
# 4     536394 2010-12-01 10:39:00    85123A
#
#                           description  quantity  unitprice  revenue  \
# 0  CREAM HANGING HEART T-LIGHT HOLDER         6       2.55     15.3
# 2  CREAM HANGING HEART T-LIGHT HOLDER         6       2.55     15.3
# 4  CREAM HANGING HEART T-LIGHT HOLDER        32       2.55     81.6
#
#    customerid         country  null
# 0       17850  United Kingdom   NaN
# 2       17850  United Kingdom   NaN
# 4       13408  United Kingdom   NaN

# %%
df.reset_index().head()
# Out:
#   index  invoiceno         invoicedate stockcode  \
# 0     0     536365 2010-12-01 08:26:00    85123A
# 1     1     536373 2010-12-01 09:02:00    85123A
# 2     2     536375 2010-12-01 09:32:00    85123A
# 3     3     536390 2010-12-01 10:19:00    85123A
# 4     4     536394 2010-12-01 10:39:00    85123A
#
#                           description  quantity  unitprice  revenue  \
# 0  CREAM HANGING HEART T-LIGHT HOLDER         6       2.55     15.3
# 1  CREAM HANGING HEART T-LIGHT HOLDER         6       2.55     15.3
# 2  CREAM HANGING HEART T-LIGHT HOLDER         6       2.55     15.3
# 3  CREAM HANGING HEART T-LIGHT HOLDER        64       2.55    163.2
# 4  CREAM HANGING HEART T-LIGHT HOLDER        32       2.55     81.6
#
#    customerid         country  null
# 0       17850  United Kingdom   NaN
# 1       17850  United Kingdom   1.0
# 2       17850  United Kingdom   NaN
# 3       17511  United Kingdom   3.0
# 4       13408  United Kingdom   NaN

# %%
df.index[:5]
# Out:
# Index(['0', '1', '2', '3', '4'], dtype='object')

# %%
df.reset_index(inplace=True)

# %%
df.index[:5]
# Out:
# RangeIndex(start=0, stop=5, step=1)

# %%
df.sample(5)   # muestra aleatoria de 5 elemento
# Out:
#          index  invoiceno         invoicedate stockcode  \
# 207749  207749     560921 2011-07-21 19:17:00     22717
# 222852  222852     567866 2011-09-22 14:13:00     22669
# 13617    13617     566213 2011-09-09 15:09:00     21791
# 247797  247797     578949 2011-11-27 14:30:00     22802
# 343746  343746     573415 2011-10-30 16:17:00     23080
#
#                                description  quantity  unitprice  revenue  \
# 207749                  CARD DOG AND BALL         12       0.42     5.04
# 222852                   RED BABY BUNTING         10       2.95    29.50
# 13617   VINTAGE HEADS AND TAILS CARD GAME         12       1.25    15.00
# 247797            FAUX FUR CHOCOLATE THROW         1      19.95    19.95
# 343746            RED METAL BOX TOP SECRET         2       8.25    16.50
#
#         customerid         country      null
# 207749       16224  United Kingdom  207749.0
# 222852       16669  United Kingdom       NaN
# 13617        14895  United Kingdom   13617.0
# 247797       14954  United Kingdom  247797.0
# 343746       13607  United Kingdom       NaN

# %%
df.sample(frac=0.1).head()  # 10% del dataframe
# Out:
#          index  invoiceno         invoicedate stockcode  \
# 351410  351410     579503 2011-11-29 16:23:00     23212
# 78692    78692     547906 2011-03-28 12:13:00     82580
# 288796  288796     544933 2011-02-25 08:44:00     84356
# 353145  353145     577740 2011-11-21 13:36:00     23270
# 228949  228949     538634 2010-12-13 13:28:00     84946
#
#                               description  quantity  unitprice  revenue  \
# 351410  HEART WREATH DECORATION WITH BELL        10       1.25     12.5
# 78692                 BATHROOM METAL SIGN         2       0.55      1.1
# 288796                     POMPOM CURTAIN        36       5.95    214.2
# 353145   SET OF 2 CERAMIC PAINTED HEARTS          6       1.45      8.7
# 228949       ANTIQUE SILVER T-LIGHT GLASS        12       1.25     15.0
#
#         customerid         country      null
# 351410       17097           Spain       NaN
# 78692        14410  United Kingdom       NaN
# 288796       12633         Germany       NaN
# 353145       17625  United Kingdom  353145.0
# 228949       14085  United Kingdom  228949.0

# %%
df._get_numeric_data().head()   # solo columnas numericas
# Out:
#    invoiceno  quantity  unitprice  revenue  customerid  null
# 0     536365         6       2.55     15.3       17850   NaN
# 1     536373         6       2.55     15.3       17850   1.0
# 2     536375         6       2.55     15.3       17850   NaN
# 3     536390        64       2.55    163.2       17511   3.0
# 4     536394        32       2.55     81.6       13408   NaN

# %%
df.select_dtypes(include='float64', exclude=['bool', 'object']).head()
# Out:
#    unitprice  revenue  null
# 0       2.55     15.3   NaN
# 1       2.55     15.3   1.0
# 2       2.55     15.3   NaN
# 3       2.55    163.2   3.0
# 4       2.55     81.6   NaN

# %%
df.select_dtypes(include='float64').head()
# Out:
#    unitprice  revenue  null
# 0       2.55     15.3   NaN
# 1       2.55     15.3   1.0
# 2       2.55     15.3   NaN
# 3       2.55    163.2   3.0
# 4       2.55     81.6   NaN

# %%
df.select_dtypes(include=['bool', 'float'], exclude=['int', 'object']).head()
# Out:
#    unitprice  revenue  null
# 0       2.55     15.3   NaN
# 1       2.55     15.3   1.0
# 2       2.55     15.3   NaN
# 3       2.55    163.2   3.0
# 4       2.55     81.6   NaN

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 396034 entries, 0 to 396033
# Data columns (total 11 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   index        396034 non-null  object
#  1   invoiceno    396034 non-null  int64
#  2   invoicedate  396034 non-null  datetime64[ns]
#  3   stockcode    396034 non-null  object
#  4   description  396034 non-null  object
#  5   quantity     396034 non-null  int64
#  6   unitprice    396034 non-null  float64
#  7   revenue      396034 non-null  float64
#  8   customerid   396034 non-null  int64
#  9   country      396034 non-null  object
#  10  null         198017 non-null  float64
# dtypes: datetime64[ns](1), float64(3), int64(3), object(4)
# memory usage: 33.2+ MB

# %% [markdown]
# ## 1

# %% [markdown]
# ### Cambio del tipo de datos

# %%
df.quantity.astype(dtype='int16').head()
# Out:
# 0     6
# 1     6
# 2     6
# 3    64
# 4    32
# Name: quantity, dtype: int16

# %%
df.info(memory_usage='deep')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 396034 entries, 0 to 396033
# Data columns (total 11 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   index        396034 non-null  object
#  1   invoiceno    396034 non-null  int64
#  2   invoicedate  396034 non-null  datetime64[ns]
#  3   stockcode    396034 non-null  object
#  4   description  396034 non-null  object
#  5   quantity     396034 non-null  int64
#  6   unitprice    396034 non-null  float64
#  7   revenue      396034 non-null  float64
#  8   customerid   396034 non-null  int64
#  9   country      396034 non-null  object
#  10  null         198017 non-null  float64
# dtypes: datetime64[ns](1), float64(3), int64(3), object(4)
# memory usage: 117.4 MB

# %%
df.quantity=df.quantity.astype(dtype='int8')

df.info(memory_usage='deep')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 396034 entries, 0 to 396033
# Data columns (total 11 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   index        396034 non-null  object
#  1   invoiceno    396034 non-null  int64
#  2   invoicedate  396034 non-null  datetime64[ns]
#  3   stockcode    396034 non-null  object
#  4   description  396034 non-null  object
#  5   quantity     396034 non-null  int8
#  6   unitprice    396034 non-null  float64
#  7   revenue      396034 non-null  float64
#  8   customerid   396034 non-null  int64
#  9   country      396034 non-null  object
#  10  null         198017 non-null  float64
# dtypes: datetime64[ns](1), float64(3), int64(2), int8(1), object(4)
# memory usage: 114.8 MB

# %% [markdown]
# ### Manejo de valores nulos

# %%
df.isna().head()
# Out:
#    index  invoiceno  invoicedate  stockcode  description  quantity  unitprice  \
# 0  False      False        False      False        False     False      False
# 1  False      False        False      False        False     False      False
# 2  False      False        False      False        False     False      False
# 3  False      False        False      False        False     False      False
# 4  False      False        False      False        False     False      False
#
#    revenue  customerid  country   null
# 0    False       False    False   True
# 1    False       False    False  False
# 2    False       False    False   True
# 3    False       False    False  False
# 4    False       False    False   True

# %%
df.notna().head()
# Out:
#    index  invoiceno  invoicedate  stockcode  description  quantity  unitprice  \
# 0   True       True         True       True         True      True       True
# 1   True       True         True       True         True      True       True
# 2   True       True         True       True         True      True       True
# 3   True       True         True       True         True      True       True
# 4   True       True         True       True         True      True       True
#
#    revenue  customerid  country   null
# 0     True        True     True  False
# 1     True        True     True   True
# 2     True        True     True  False
# 3     True        True     True   True
# 4     True        True     True  False

# %%
df.isnull().head()
# Out:
#    index  invoiceno  invoicedate  stockcode  description  quantity  unitprice  \
# 0  False      False        False      False        False     False      False
# 1  False      False        False      False        False     False      False
# 2  False      False        False      False        False     False      False
# 3  False      False        False      False        False     False      False
# 4  False      False        False      False        False     False      False
#
#    revenue  customerid  country   null
# 0    False       False    False   True
# 1    False       False    False  False
# 2    False       False    False   True
# 3    False       False    False  False
# 4    False       False    False   True

# %%
sum([True, False, False, True, True])
# Out:
# 3

# %%
nan_cols=df.isna().sum()  # suma de elementos nulos

nan_cols
# Out:
# index               0
# invoiceno           0
# invoicedate         0
# stockcode           0
# description         0
# quantity            0
# unitprice           0
# revenue             0
# customerid          0
# country             0
# null           198017
# dtype: int64

# %%
nan_cols[nan_cols>0]
# Out:
# null    198017
# dtype: int64

# %% [markdown]
# **¿Qué hacemos?**

# %%
# podemos rellenar

df.fillna(0).head()
# Out:
#   index  invoiceno         invoicedate stockcode  \
# 0     0     536365 2010-12-01 08:26:00    85123A
# 1     1     536373 2010-12-01 09:02:00    85123A
# 2     2     536375 2010-12-01 09:32:00    85123A
# 3     3     536390 2010-12-01 10:19:00    85123A
# 4     4     536394 2010-12-01 10:39:00    85123A
#
#                           description  quantity  unitprice  revenue  \
# 0  CREAM HANGING HEART T-LIGHT HOLDER         6       2.55     15.3
# 1  CREAM HANGING HEART T-LIGHT HOLDER         6       2.55     15.3
# 2  CREAM HANGING HEART T-LIGHT HOLDER         6       2.55     15.3
# 3  CREAM HANGING HEART T-LIGHT HOLDER        64       2.55    163.2
# 4  CREAM HANGING HEART T-LIGHT HOLDER        32       2.55     81.6
#
#    customerid         country  null
# 0       17850  United Kingdom   0.0
# 1       17850  United Kingdom   1.0
# 2       17850  United Kingdom   0.0
# 3       17511  United Kingdom   3.0
# 4       13408  United Kingdom   0.0

# %%
df.null.fillna('hola').head()
# Out:
# 0    hola
# 1     1.0
# 2    hola
# 3     3.0
# 4    hola
# Name: null, dtype: object

# %%
for e in df.null.fillna('hola').head():
    try:
        print(e.lower())
    except:
        print(e)
# Out:
# hola
# 1.0
# hola
# 3.0
# hola

# %%
for e in df.null.fillna('hola').head():
    
    print(e*2)
# Out:
# holahola
# 2.0
# holahola
# 6.0
# holahola

# %%
for e in df.null.fillna('hola').head():
    
    if type(e)==str:
        print(e.upper())
        
    elif type(e)==float:
        print(e**2)
# Out:
# HOLA
# 1.0
# HOLA
# 9.0
# HOLA

# %%
df.head()
# Out:
#   index  invoiceno         invoicedate stockcode  \
# 0     0     536365 2010-12-01 08:26:00    85123A
# 1     1     536373 2010-12-01 09:02:00    85123A
# 2     2     536375 2010-12-01 09:32:00    85123A
# 3     3     536390 2010-12-01 10:19:00    85123A
# 4     4     536394 2010-12-01 10:39:00    85123A
#
#                           description  quantity  unitprice  revenue  \
# 0  CREAM HANGING HEART T-LIGHT HOLDER         6       2.55     15.3
# 1  CREAM HANGING HEART T-LIGHT HOLDER         6       2.55     15.3
# 2  CREAM HANGING HEART T-LIGHT HOLDER         6       2.55     15.3
# 3  CREAM HANGING HEART T-LIGHT HOLDER        64       2.55    163.2
# 4  CREAM HANGING HEART T-LIGHT HOLDER        32       2.55     81.6
#
#    customerid         country  null
# 0       17850  United Kingdom   NaN
# 1       17850  United Kingdom   1.0
# 2       17850  United Kingdom   NaN
# 3       17511  United Kingdom   3.0
# 4       13408  United Kingdom   NaN

# %%
df.fillna(df.null.mean()).head()
# Out:
#   index  invoiceno         invoicedate stockcode  \
# 0     0     536365 2010-12-01 08:26:00    85123A
# 1     1     536373 2010-12-01 09:02:00    85123A
# 2     2     536375 2010-12-01 09:32:00    85123A
# 3     3     536390 2010-12-01 10:19:00    85123A
# 4     4     536394 2010-12-01 10:39:00    85123A
#
#                           description  quantity  unitprice  revenue  \
# 0  CREAM HANGING HEART T-LIGHT HOLDER         6       2.55     15.3
# 1  CREAM HANGING HEART T-LIGHT HOLDER         6       2.55     15.3
# 2  CREAM HANGING HEART T-LIGHT HOLDER         6       2.55     15.3
# 3  CREAM HANGING HEART T-LIGHT HOLDER        64       2.55    163.2
# 4  CREAM HANGING HEART T-LIGHT HOLDER        32       2.55     81.6
#
#    customerid         country      null
# 0       17850  United Kingdom  198017.0
# 1       17850  United Kingdom       1.0
# 2       17850  United Kingdom  198017.0
# 3       17511  United Kingdom       3.0
# 4       13408  United Kingdom  198017.0

# %%
df.fillna(df.null.median()).head()
# Out:
#   index  invoiceno         invoicedate stockcode  \
# 0     0     536365 2010-12-01 08:26:00    85123A
# 1     1     536373 2010-12-01 09:02:00    85123A
# 2     2     536375 2010-12-01 09:32:00    85123A
# 3     3     536390 2010-12-01 10:19:00    85123A
# 4     4     536394 2010-12-01 10:39:00    85123A
#
#                           description  quantity  unitprice  revenue  \
# 0  CREAM HANGING HEART T-LIGHT HOLDER         6       2.55     15.3
# 1  CREAM HANGING HEART T-LIGHT HOLDER         6       2.55     15.3
# 2  CREAM HANGING HEART T-LIGHT HOLDER         6       2.55     15.3
# 3  CREAM HANGING HEART T-LIGHT HOLDER        64       2.55    163.2
# 4  CREAM HANGING HEART T-LIGHT HOLDER        32       2.55     81.6
#
#    customerid         country      null
# 0       17850  United Kingdom  198017.0
# 1       17850  United Kingdom       1.0
# 2       17850  United Kingdom  198017.0
# 3       17511  United Kingdom       3.0
# 4       13408  United Kingdom  198017.0

# %%
# podemos borrar la columna

df.drop('null', axis=1).head()
# Out:
#   index  invoiceno         invoicedate stockcode  \
# 0     0     536365 2010-12-01 08:26:00    85123A
# 1     1     536373 2010-12-01 09:02:00    85123A
# 2     2     536375 2010-12-01 09:32:00    85123A
# 3     3     536390 2010-12-01 10:19:00    85123A
# 4     4     536394 2010-12-01 10:39:00    85123A
#
#                           description  quantity  unitprice  revenue  \
# 0  CREAM HANGING HEART T-LIGHT HOLDER         6       2.55     15.3
# 1  CREAM HANGING HEART T-LIGHT HOLDER         6       2.55     15.3
# 2  CREAM HANGING HEART T-LIGHT HOLDER         6       2.55     15.3
# 3  CREAM HANGING HEART T-LIGHT HOLDER        64       2.55    163.2
# 4  CREAM HANGING HEART T-LIGHT HOLDER        32       2.55     81.6
#
#    customerid         country
# 0       17850  United Kingdom
# 1       17850  United Kingdom
# 2       17850  United Kingdom
# 3       17511  United Kingdom
# 4       13408  United Kingdom

# %%
df.drop(columns=['null', 'quantity', 'unitprice', 'index']).head()
# Out:
#    invoiceno         invoicedate stockcode  \
# 0     536365 2010-12-01 08:26:00    85123A
# 1     536373 2010-12-01 09:02:00    85123A
# 2     536375 2010-12-01 09:32:00    85123A
# 3     536390 2010-12-01 10:19:00    85123A
# 4     536394 2010-12-01 10:39:00    85123A
#
#                           description  revenue  customerid         country
# 0  CREAM HANGING HEART T-LIGHT HOLDER     15.3       17850  United Kingdom
# 1  CREAM HANGING HEART T-LIGHT HOLDER     15.3       17850  United Kingdom
# 2  CREAM HANGING HEART T-LIGHT HOLDER     15.3       17850  United Kingdom
# 3  CREAM HANGING HEART T-LIGHT HOLDER    163.2       17511  United Kingdom
# 4  CREAM HANGING HEART T-LIGHT HOLDER     81.6       13408  United Kingdom

# %%
df[df.null.notna()].head()
# Out:
#   index  invoiceno         invoicedate stockcode  \
# 1     1     536373 2010-12-01 09:02:00    85123A
# 3     3     536390 2010-12-01 10:19:00    85123A
# 5     5     536396 2010-12-01 10:51:00    85123A
# 7     7     536406 2010-12-01 11:33:00    85123A
# 9     9     536520 2010-12-01 12:43:00    85123A
#
#                           description  quantity  unitprice  revenue  \
# 1  CREAM HANGING HEART T-LIGHT HOLDER         6       2.55    15.30
# 3  CREAM HANGING HEART T-LIGHT HOLDER        64       2.55   163.20
# 5  CREAM HANGING HEART T-LIGHT HOLDER         6       2.55    15.30
# 7  CREAM HANGING HEART T-LIGHT HOLDER         8       2.55    20.40
# 9  CREAM HANGING HEART T-LIGHT HOLDER         3       2.95     8.85
#
#    customerid         country  null
# 1       17850  United Kingdom   1.0
# 3       17511  United Kingdom   3.0
# 5       17850  United Kingdom   5.0
# 7       17850  United Kingdom   7.0
# 9       14729  United Kingdom   9.0

# %%
df.dropna(axis=0).head()  # esto borraria todo
# Out:
#   index  invoiceno         invoicedate stockcode  \
# 1     1     536373 2010-12-01 09:02:00    85123A
# 3     3     536390 2010-12-01 10:19:00    85123A
# 5     5     536396 2010-12-01 10:51:00    85123A
# 7     7     536406 2010-12-01 11:33:00    85123A
# 9     9     536520 2010-12-01 12:43:00    85123A
#
#                           description  quantity  unitprice  revenue  \
# 1  CREAM HANGING HEART T-LIGHT HOLDER         6       2.55    15.30
# 3  CREAM HANGING HEART T-LIGHT HOLDER        64       2.55   163.20
# 5  CREAM HANGING HEART T-LIGHT HOLDER         6       2.55    15.30
# 7  CREAM HANGING HEART T-LIGHT HOLDER         8       2.55    20.40
# 9  CREAM HANGING HEART T-LIGHT HOLDER         3       2.95     8.85
#
#    customerid         country  null
# 1       17850  United Kingdom   1.0
# 3       17511  United Kingdom   3.0
# 5       17850  United Kingdom   5.0
# 7       17850  United Kingdom   7.0
# 9       14729  United Kingdom   9.0

# %%
# solo donde la columna null es nula

df.dropna(subset='null', axis=0).head()
# Out:
#   index  invoiceno         invoicedate stockcode  \
# 1     1     536373 2010-12-01 09:02:00    85123A
# 3     3     536390 2010-12-01 10:19:00    85123A
# 5     5     536396 2010-12-01 10:51:00    85123A
# 7     7     536406 2010-12-01 11:33:00    85123A
# 9     9     536520 2010-12-01 12:43:00    85123A
#
#                           description  quantity  unitprice  revenue  \
# 1  CREAM HANGING HEART T-LIGHT HOLDER         6       2.55    15.30
# 3  CREAM HANGING HEART T-LIGHT HOLDER        64       2.55   163.20
# 5  CREAM HANGING HEART T-LIGHT HOLDER         6       2.55    15.30
# 7  CREAM HANGING HEART T-LIGHT HOLDER         8       2.55    20.40
# 9  CREAM HANGING HEART T-LIGHT HOLDER         3       2.95     8.85
#
#    customerid         country  null
# 1       17850  United Kingdom   1.0
# 3       17511  United Kingdom   3.0
# 5       17850  United Kingdom   5.0
# 7       17850  United Kingdom   7.0
# 9       14729  United Kingdom   9.0

# %%
df.dropna(subset=['null', 'quantity'], axis=0).head()
# Out:
#   index  invoiceno         invoicedate stockcode  \
# 1     1     536373 2010-12-01 09:02:00    85123A
# 3     3     536390 2010-12-01 10:19:00    85123A
# 5     5     536396 2010-12-01 10:51:00    85123A
# 7     7     536406 2010-12-01 11:33:00    85123A
# 9     9     536520 2010-12-01 12:43:00    85123A
#
#                           description  quantity  unitprice  revenue  \
# 1  CREAM HANGING HEART T-LIGHT HOLDER         6       2.55    15.30
# 3  CREAM HANGING HEART T-LIGHT HOLDER        64       2.55   163.20
# 5  CREAM HANGING HEART T-LIGHT HOLDER         6       2.55    15.30
# 7  CREAM HANGING HEART T-LIGHT HOLDER         8       2.55    20.40
# 9  CREAM HANGING HEART T-LIGHT HOLDER         3       2.95     8.85
#
#    customerid         country  null
# 1       17850  United Kingdom   1.0
# 3       17511  United Kingdom   3.0
# 5       17850  United Kingdom   5.0
# 7       17850  United Kingdom   7.0
# 9       14729  United Kingdom   9.0

# %%
# eliminar duplicados

df.drop_duplicates().head()
# Out:
#   index  invoiceno         invoicedate stockcode  \
# 0     0     536365 2010-12-01 08:26:00    85123A
# 1     1     536373 2010-12-01 09:02:00    85123A
# 2     2     536375 2010-12-01 09:32:00    85123A
# 3     3     536390 2010-12-01 10:19:00    85123A
# 4     4     536394 2010-12-01 10:39:00    85123A
#
#                           description  quantity  unitprice  revenue  \
# 0  CREAM HANGING HEART T-LIGHT HOLDER         6       2.55     15.3
# 1  CREAM HANGING HEART T-LIGHT HOLDER         6       2.55     15.3
# 2  CREAM HANGING HEART T-LIGHT HOLDER         6       2.55     15.3
# 3  CREAM HANGING HEART T-LIGHT HOLDER        64       2.55    163.2
# 4  CREAM HANGING HEART T-LIGHT HOLDER        32       2.55     81.6
#
#    customerid         country  null
# 0       17850  United Kingdom   NaN
# 1       17850  United Kingdom   1.0
# 2       17850  United Kingdom   NaN
# 3       17511  United Kingdom   3.0
# 4       13408  United Kingdom   NaN

# %%
df.drop_duplicates(subset=['country', 'null']).reset_index(drop=True).head()
# Out:
#   index  invoiceno         invoicedate stockcode  \
# 0     0     536365 2010-12-01 08:26:00    85123A
# 1     1     536373 2010-12-01 09:02:00    85123A
# 2     3     536390 2010-12-01 10:19:00    85123A
# 3     5     536396 2010-12-01 10:51:00    85123A
# 4     7     536406 2010-12-01 11:33:00    85123A
#
#                           description  quantity  unitprice  revenue  \
# 0  CREAM HANGING HEART T-LIGHT HOLDER         6       2.55     15.3
# 1  CREAM HANGING HEART T-LIGHT HOLDER         6       2.55     15.3
# 2  CREAM HANGING HEART T-LIGHT HOLDER        64       2.55    163.2
# 3  CREAM HANGING HEART T-LIGHT HOLDER         6       2.55     15.3
# 4  CREAM HANGING HEART T-LIGHT HOLDER         8       2.55     20.4
#
#    customerid         country  null
# 0       17850  United Kingdom   NaN
# 1       17850  United Kingdom   1.0
# 2       17511  United Kingdom   3.0
# 3       17850  United Kingdom   5.0
# 4       17850  United Kingdom   7.0

# %%
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [index, invoiceno, invoicedate, stockcode, description, quantity, unitprice, revenue, customerid, country, null]
# Index: []

# %% [markdown]
# ### Agrupación

# %%
# para agrupar SIEMPRE se necesita una funcion de agragacion

df.groupby('country').mean().head()
# Out:
#                invoiceno   quantity  unitprice     revenue    customerid  \
# country
# Australia  556195.569009  18.367485   2.762489  116.995182  12454.574090
# Austria    562611.684896   9.947917   2.984115   22.767396  12521.828125
# Bahrain    552790.411765  15.294118   4.644118   32.258824  12354.529412
# Belgium    560603.708527  11.469767   3.042817   19.083897  12431.118346
# Brazil     550201.000000  11.125000   4.456250   35.737500  12769.000000
#
#                     null
# country
# Australia  204905.351494
# Austria    192307.557895
# Bahrain    216702.333333
# Belgium    199700.586777
# Brazil     193760.285714

# %%
df.groupby('country').agg({'quantity': 'sum',
                           'revenue': ['mean', 'std'], 
                           'unitprice': 'mean'}).head()
# Out:
#           quantity     revenue             unitprice
#                sum        mean         std      mean
# country
# Australia    21692  116.995182  159.820336  2.762489
# Austria       3820   22.767396   27.401579  2.984115
# Bahrain        260   32.258824   26.878478  4.644118
# Belgium      22194   19.083897   13.235034  3.042817
# Brazil         356   35.737500   32.896282  4.456250

# %%
df.groupby('country').agg({'quantity': 'sum',
                           'revenue': ['mean', 'std'], 
                           'unitprice': 'mean'}).reset_index().head()
# Out:
#      country quantity     revenue             unitprice
#                   sum        mean         std      mean
# 0  Australia    21692  116.995182  159.820336  2.762489
# 1    Austria     3820   22.767396   27.401579  2.984115
# 2    Bahrain      260   32.258824   26.878478  4.644118
# 3    Belgium    22194   19.083897   13.235034  3.042817
# 4     Brazil      356   35.737500   32.896282  4.456250

# %%
def suma(x):
    
    """
    recibe una serie, devuelve un nº
    """
    
    return sum(x+2)

# %%
df.groupby('country').agg({'quantity': sum,
                           'revenue': ['mean', 'std'], 
                           'unitprice': 'mean'}).reset_index().head()
# Out:
#      country quantity     revenue             unitprice
#                   sum        mean         std      mean
# 0  Australia    21692  116.995182  159.820336  2.762489
# 1    Austria     3820   22.767396   27.401579  2.984115
# 2    Bahrain      260   32.258824   26.878478  4.644118
# 3    Belgium    22194   19.083897   13.235034  3.042817
# 4     Brazil      356   35.737500   32.896282  4.456250

# %%
df.groupby('country').agg({'quantity': suma,
                           'revenue': ['mean', 'std'], 
                           'unitprice': 'mean'}).reset_index().head()
# Out:
#      country quantity     revenue             unitprice
#                  suma        mean         std      mean
# 0  Australia    24054  116.995182  159.820336  2.762489
# 1    Austria     4588   22.767396   27.401579  2.984115
# 2    Bahrain      294   32.258824   26.878478  4.644118
# 3    Belgium    26064   19.083897   13.235034  3.042817
# 4     Brazil      420   35.737500   32.896282  4.456250

# %%
df.groupby('country').agg({'unitprice': ['mean', 'std', 'median']}).reset_index().head()
# Out:
#      country unitprice
#                   mean       std median
# 0  Australia  2.762489  2.424046   1.79
# 1    Austria  2.984115  3.161760   1.95
# 2    Bahrain  4.644118  3.673634   2.95
# 3    Belgium  3.042817  3.402533   1.95
# 4     Brazil  4.456250  2.831727   3.32

# %%
df.groupby(['country', 'unitprice']).agg(max).head()
# Out:
#                       index  invoiceno         invoicedate  \
# country   unitprice
# Australia 0.19        65858     578459 2011-11-24 12:30:00
#           0.25       170927     545475 2011-03-03 10:59:00
#           0.29       320717     559919 2011-07-13 15:30:00
#           0.34       373541     563614 2011-08-18 08:51:00
#           0.36        54815     569650 2011-10-05 12:44:00
#
#                                           description  quantity  revenue  \
# country   unitprice
# Australia 0.19          STAR DECORATION PAINTED ZINC         96    45.60
#           0.25           PACK OF 12 WOODLAND TISSUES        -80   108.00
#           0.29       FRENCH STYLE STORAGE JAR BONBONS        48    69.60
#           0.34                       WRAP WEDDING DAY       -56   136.00
#           0.36                VINTAGE KID DOLLY CARD        120   103.68
#
#                      customerid      null
# country   unitprice
# Australia 0.19            12415       NaN
#           0.25            12415  170927.0
#           0.29            12415  320717.0
#           0.34            12415  373541.0
#           0.36            12415  388229.0

# %%
df.groupby(['country', 'unitprice']).agg('mean').head()
# Out:
#                          invoiceno   quantity     revenue    customerid  \
# country   unitprice
# Australia 0.19       566002.500000  40.000000   31.920000  12401.500000
#           0.25       545475.000000 -80.000000  108.000000  12415.000000
#           0.29       558418.000000  16.000000   41.760000  12415.000000
#           0.34       555813.050000 -61.600000   74.800000  12415.000000
#           0.36       553949.882353 -11.411765   60.945882  12414.147059
#
#                               null
# country   unitprice
# Australia 0.19                 NaN
#           0.25       170419.666667
#           0.29       274236.000000
#           0.34       275419.000000
#           0.36       170596.375000

# %%
df.groupby(['country', 'unitprice']).agg('mean').sort_values(by='revenue').head()
# Out:
#                           invoiceno  quantity  revenue  customerid      null
# country        unitprice
# United Kingdom 0.76        548568.0       1.0     0.76     14543.0  164143.0
# Netherlands    0.82        572236.0       1.0     0.82     14646.0  375327.0
# Israel         0.95        569527.0       1.0     0.95     12512.0       NaN
# Cyprus         0.95        577228.0       1.0     0.95     12391.0  115359.0
# Portugal       0.19        569866.0       6.0     1.14     12757.0  278277.0

# %%
grupo=df.groupby(['country', 'unitprice']).agg('mean')

# %%
grupo.columns
# Out:
# Index(['invoiceno', 'quantity', 'revenue', 'customerid', 'null'], dtype='object')

# %%
grupo.revenue.head()
# Out:
# country    unitprice
# Australia  0.19          31.920000
#            0.25         108.000000
#            0.29          41.760000
#            0.34          74.800000
#            0.36          60.945882
# Name: revenue, dtype: float64

# %% [markdown]
# ### Pivot table
#
# https://archive.ics.uci.edu/ml/datasets/Student+Performance

# %%
students = pd.read_csv('../data/student-por.csv', sep=';')

students.head()
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  ...  \
# 0     GP   F   18       U     GT3       A     4     4  at_home   teacher  ...
# 1     GP   F   17       U     GT3       T     1     1  at_home     other  ...
# 2     GP   F   15       U     LE3       T     1     1  at_home     other  ...
# 3     GP   F   15       U     GT3       T     4     2   health  services  ...
# 4     GP   F   16       U     GT3       T     3     3    other     other  ...
#
#   famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 0      4        3      4     1     1      3        4   0  11  11
# 1      5        3      3     1     1      3        2   9  11  11
# 2      4        3      2     2     3      3        6  12  13  12
# 3      3        2      2     1     1      5        0  14  14  14
# 4      4        3      2     1     2      5        0  11  13  13
#
# [5 rows x 33 columns]

# %%
students.school.unique()
# Out:
# array(['GP', 'MS'], dtype=object)

# %%
students.pivot_table(index=['school'], columns=['sex'])
# Out:
#             Dalc                Fedu                   G1             \
# sex            F         M         F         M          F          M
# school
# GP      1.291139  1.698925  2.396624  2.575269  12.286920  11.602151
# MS      1.273973  2.087500  1.958904  2.050000  10.582192   9.787500
#
#                G2                    G3             ...  freetime            \
# sex             F          M          F          M  ...         F         M
# school                                              ...
# GP      12.502110  11.688172  13.004219  12.032258  ...  2.953586  3.408602
# MS      10.719178  10.087500  11.034247   9.950000  ...  3.212329  3.262500
#
#            goout              health           studytime           traveltime  \
# sex            F         M         F         M         F         M          F
# school
# GP      3.109705  3.193548  3.464135  3.768817  2.189873  1.790323   1.405063
# MS      3.157534  3.437500  3.212329  3.800000  1.883562  1.575000   1.767123
#
#
# sex            M
# school
# GP      1.462366
# MS      1.937500
#
# [2 rows x 32 columns]

# %%
#help(students.pivot_table)

# %%
students.pivot_table(index=['school'], columns=['sex'], aggfunc='max')
# Out:
#        Dalc    Fedu        Fjob           G1      G2      ...      reason  \
# sex       F  M    F  M        F        M   F   M   F   M  ...           F
# school                                                    ...
# GP        5  5    4  4  teacher  teacher  18  18  19  18  ...  reputation
# MS        4  5    4  4  teacher  teacher  19  17  18  18  ...  reputation
#
#                    romantic      schoolsup      studytime    traveltime
# sex              M        F    M         F    M         F  M          F  M
# school
# GP      reputation      yes  yes       yes  yes         4  4          4  4
# MS      reputation      yes  yes       yes  yes         4  4          4  4
#
# [2 rows x 62 columns]

# %%
students.pivot_table(index=['school'], 
                     columns=['sex'], 
                     aggfunc='count',
                    values=['G3'])
# Out:
#          G3
# sex       F    M
# school
# GP      237  186
# MS      146   80

# %% [markdown]
# pandas.pivot_table(data, values=None, index=None, columns=None, aggfunc='mean', fill_value=None, margins=False, dropna=True, margins_name='All', observed=False, sort=True)

# %% [markdown]
# ### Cross table

# %%
pd.crosstab(index=students.sex, columns='count')
# Out:
# col_0  count
# sex
# F        383
# M        266

# %%
pd.crosstab(index=students.sex, columns=students.activities)
# Out:
# activities   no  yes
# sex
# F           217  166
# M           117  149

# %%
cross=pd.crosstab(index=students.sex, columns=students.activities)

cross * 100 / cross.sum().sum()
# Out:
# activities         no        yes
# sex
# F           33.436055  25.577812
# M           18.027735  22.958398

# %%
cross = cross * 100 / cross.sum().sum()

cross.T
# Out:
# sex                 F          M
# activities
# no          33.436055  18.027735
# yes         25.577812  22.958398

# %%
cross['nueva']=0

cross
# Out:
# activities         no        yes  nueva
# sex
# F           33.436055  25.577812      0
# M           18.027735  22.958398      0

# %%
pd.crosstab(index=students.sex, 
            columns=students.famsize,
           values=students.absences,
           aggfunc='count')
# Out:
# famsize  GT3  LE3
# sex
# F        284   99
# M        173   93

# %%
pd.crosstab(index=students.sex, 
            columns=students.famsize, 
            values=students.absences, 
            aggfunc='mean')
# Out:
# famsize       GT3       LE3
# sex
# F        3.616197  3.464646
# M        3.693642  3.935484

# %%
pd.crosstab(index=students.sex, 
            columns=students.famsize, 
            values=students.absences, 
            aggfunc='mean')
# Out:
# famsize       GT3       LE3
# sex
# F        3.616197  3.464646
# M        3.693642  3.935484

# %% [markdown]
# ### Aplicación de funciones

# %%
df.head()
# Out:
#   index  invoiceno         invoicedate stockcode  \
# 0     0     536365 2010-12-01 08:26:00    85123A
# 1     1     536373 2010-12-01 09:02:00    85123A
# 2     2     536375 2010-12-01 09:32:00    85123A
# 3     3     536390 2010-12-01 10:19:00    85123A
# 4     4     536394 2010-12-01 10:39:00    85123A
#
#                           description  quantity  unitprice  revenue  \
# 0  CREAM HANGING HEART T-LIGHT HOLDER         6       2.55     15.3
# 1  CREAM HANGING HEART T-LIGHT HOLDER         6       2.55     15.3
# 2  CREAM HANGING HEART T-LIGHT HOLDER         6       2.55     15.3
# 3  CREAM HANGING HEART T-LIGHT HOLDER        64       2.55    163.2
# 4  CREAM HANGING HEART T-LIGHT HOLDER        32       2.55     81.6
#
#    customerid         country  null
# 0       17850  United Kingdom   NaN
# 1       17850  United Kingdom   1.0
# 2       17850  United Kingdom   NaN
# 3       17511  United Kingdom   3.0
# 4       13408  United Kingdom   NaN

# %%
def suma(x):
    return x+2

# %%
# %%time

df.quantity=[suma(x) for x in df.quantity]

df.head()
# Out:
# CPU times: user 70.4 ms, sys: 2.83 ms, total: 73.3 ms
# Wall time: 82.6 ms
#   index  invoiceno         invoicedate stockcode  \
# 0     0     536365 2010-12-01 08:26:00    85123A
# 1     1     536373 2010-12-01 09:02:00    85123A
# 2     2     536375 2010-12-01 09:32:00    85123A
# 3     3     536390 2010-12-01 10:19:00    85123A
# 4     4     536394 2010-12-01 10:39:00    85123A
#
#                           description  quantity  unitprice  revenue  \
# 0  CREAM HANGING HEART T-LIGHT HOLDER         8       2.55     15.3
# 1  CREAM HANGING HEART T-LIGHT HOLDER         8       2.55     15.3
# 2  CREAM HANGING HEART T-LIGHT HOLDER         8       2.55     15.3
# 3  CREAM HANGING HEART T-LIGHT HOLDER        66       2.55    163.2
# 4  CREAM HANGING HEART T-LIGHT HOLDER        34       2.55     81.6
#
#    customerid         country  null
# 0       17850  United Kingdom   NaN
# 1       17850  United Kingdom   1.0
# 2       17850  United Kingdom   NaN
# 3       17511  United Kingdom   3.0
# 4       13408  United Kingdom   NaN

# %%
# %%time

df.quantity=list(map(suma, df.quantity))

df.head()
# Out:
# CPU times: user 62.1 ms, sys: 3.25 ms, total: 65.4 ms
# Wall time: 64.6 ms
#   index  invoiceno         invoicedate stockcode  \
# 0     0     536365 2010-12-01 08:26:00    85123A
# 1     1     536373 2010-12-01 09:02:00    85123A
# 2     2     536375 2010-12-01 09:32:00    85123A
# 3     3     536390 2010-12-01 10:19:00    85123A
# 4     4     536394 2010-12-01 10:39:00    85123A
#
#                           description  quantity  unitprice  revenue  \
# 0  CREAM HANGING HEART T-LIGHT HOLDER        10       2.55     15.3
# 1  CREAM HANGING HEART T-LIGHT HOLDER        10       2.55     15.3
# 2  CREAM HANGING HEART T-LIGHT HOLDER        10       2.55     15.3
# 3  CREAM HANGING HEART T-LIGHT HOLDER        68       2.55    163.2
# 4  CREAM HANGING HEART T-LIGHT HOLDER        36       2.55     81.6
#
#    customerid         country  null
# 0       17850  United Kingdom   NaN
# 1       17850  United Kingdom   1.0
# 2       17850  United Kingdom   NaN
# 3       17511  United Kingdom   3.0
# 4       13408  United Kingdom   NaN

# %%
# %%time

df.quantity=list(map(lambda x: x+2, df.quantity))

df.head()
# Out:
# CPU times: user 91.6 ms, sys: 4.45 ms, total: 96.1 ms
# Wall time: 94.2 ms
#   index  invoiceno         invoicedate stockcode  \
# 0     0     536365 2010-12-01 08:26:00    85123A
# 1     1     536373 2010-12-01 09:02:00    85123A
# 2     2     536375 2010-12-01 09:32:00    85123A
# 3     3     536390 2010-12-01 10:19:00    85123A
# 4     4     536394 2010-12-01 10:39:00    85123A
#
#                           description  quantity  unitprice  revenue  \
# 0  CREAM HANGING HEART T-LIGHT HOLDER        12       2.55     15.3
# 1  CREAM HANGING HEART T-LIGHT HOLDER        12       2.55     15.3
# 2  CREAM HANGING HEART T-LIGHT HOLDER        12       2.55     15.3
# 3  CREAM HANGING HEART T-LIGHT HOLDER        70       2.55    163.2
# 4  CREAM HANGING HEART T-LIGHT HOLDER        38       2.55     81.6
#
#    customerid         country  null
# 0       17850  United Kingdom   NaN
# 1       17850  United Kingdom   1.0
# 2       17850  United Kingdom   NaN
# 3       17511  United Kingdom   3.0
# 4       13408  United Kingdom   NaN

# %%
# %%time

df.quantity=df.quantity.apply(suma)

df.head()
# Out:
# CPU times: user 82.2 ms, sys: 4.77 ms, total: 86.9 ms
# Wall time: 85 ms
#   index  invoiceno         invoicedate stockcode  \
# 0     0     536365 2010-12-01 08:26:00    85123A
# 1     1     536373 2010-12-01 09:02:00    85123A
# 2     2     536375 2010-12-01 09:32:00    85123A
# 3     3     536390 2010-12-01 10:19:00    85123A
# 4     4     536394 2010-12-01 10:39:00    85123A
#
#                           description  quantity  unitprice  revenue  \
# 0  CREAM HANGING HEART T-LIGHT HOLDER        14       2.55     15.3
# 1  CREAM HANGING HEART T-LIGHT HOLDER        14       2.55     15.3
# 2  CREAM HANGING HEART T-LIGHT HOLDER        14       2.55     15.3
# 3  CREAM HANGING HEART T-LIGHT HOLDER        72       2.55    163.2
# 4  CREAM HANGING HEART T-LIGHT HOLDER        40       2.55     81.6
#
#    customerid         country  null
# 0       17850  United Kingdom   NaN
# 1       17850  United Kingdom   1.0
# 2       17850  United Kingdom   NaN
# 3       17511  United Kingdom   3.0
# 4       13408  United Kingdom   NaN

# %%
# %%time

df.quantity=df.quantity.apply(lambda x: x+2)

df.head()
# Out:
# CPU times: user 80.3 ms, sys: 4.24 ms, total: 84.6 ms
# Wall time: 82.1 ms
#   index  invoiceno         invoicedate stockcode  \
# 0     0     536365 2010-12-01 08:26:00    85123A
# 1     1     536373 2010-12-01 09:02:00    85123A
# 2     2     536375 2010-12-01 09:32:00    85123A
# 3     3     536390 2010-12-01 10:19:00    85123A
# 4     4     536394 2010-12-01 10:39:00    85123A
#
#                           description  quantity  unitprice  revenue  \
# 0  CREAM HANGING HEART T-LIGHT HOLDER        16       2.55     15.3
# 1  CREAM HANGING HEART T-LIGHT HOLDER        16       2.55     15.3
# 2  CREAM HANGING HEART T-LIGHT HOLDER        16       2.55     15.3
# 3  CREAM HANGING HEART T-LIGHT HOLDER        74       2.55    163.2
# 4  CREAM HANGING HEART T-LIGHT HOLDER        42       2.55     81.6
#
#    customerid         country  null
# 0       17850  United Kingdom   NaN
# 1       17850  United Kingdom   1.0
# 2       17850  United Kingdom   NaN
# 3       17511  United Kingdom   3.0
# 4       13408  United Kingdom   NaN

# %%
# %%time

df.quantity=df.quantity + 2

df.head()
# Out:
# CPU times: user 3.5 ms, sys: 3.32 ms, total: 6.82 ms
# Wall time: 4.45 ms
#   index  invoiceno         invoicedate stockcode  \
# 0     0     536365 2010-12-01 08:26:00    85123A
# 1     1     536373 2010-12-01 09:02:00    85123A
# 2     2     536375 2010-12-01 09:32:00    85123A
# 3     3     536390 2010-12-01 10:19:00    85123A
# 4     4     536394 2010-12-01 10:39:00    85123A
#
#                           description  quantity  unitprice  revenue  \
# 0  CREAM HANGING HEART T-LIGHT HOLDER        18       2.55     15.3
# 1  CREAM HANGING HEART T-LIGHT HOLDER        18       2.55     15.3
# 2  CREAM HANGING HEART T-LIGHT HOLDER        18       2.55     15.3
# 3  CREAM HANGING HEART T-LIGHT HOLDER        76       2.55    163.2
# 4  CREAM HANGING HEART T-LIGHT HOLDER        44       2.55     81.6
#
#    customerid         country  null
# 0       17850  United Kingdom   NaN
# 1       17850  United Kingdom   1.0
# 2       17850  United Kingdom   NaN
# 3       17511  United Kingdom   3.0
# 4       13408  United Kingdom   NaN

# %%
# %%time

df['nueva'] = df.quantity / df.unitprice

df.head()
# Out:
# CPU times: user 4.09 ms, sys: 3.28 ms, total: 7.37 ms
# Wall time: 4.18 ms
#   index  invoiceno         invoicedate stockcode  \
# 0     0     536365 2010-12-01 08:26:00    85123A
# 1     1     536373 2010-12-01 09:02:00    85123A
# 2     2     536375 2010-12-01 09:32:00    85123A
# 3     3     536390 2010-12-01 10:19:00    85123A
# 4     4     536394 2010-12-01 10:39:00    85123A
#
#                           description  quantity  unitprice  revenue  \
# 0  CREAM HANGING HEART T-LIGHT HOLDER        18       2.55     15.3
# 1  CREAM HANGING HEART T-LIGHT HOLDER        18       2.55     15.3
# 2  CREAM HANGING HEART T-LIGHT HOLDER        18       2.55     15.3
# 3  CREAM HANGING HEART T-LIGHT HOLDER        76       2.55    163.2
# 4  CREAM HANGING HEART T-LIGHT HOLDER        44       2.55     81.6
#
#    customerid         country  null      nueva
# 0       17850  United Kingdom   NaN   7.058824
# 1       17850  United Kingdom   1.0   7.058824
# 2       17850  United Kingdom   NaN   7.058824
# 3       17511  United Kingdom   3.0  29.803922
# 4       13408  United Kingdom   NaN  17.254902

# %%
# %%time

lst = []

for i in range(len(df)):
    
    valor = df.quantity[i] / df.unitprice[i]
    
    lst.append(valor)
    
df['nueva_2']=lst

df.head()
# Out:
# CPU times: user 2.88 s, sys: 9.9 ms, total: 2.89 s
# Wall time: 2.89 s
#   index  invoiceno         invoicedate stockcode  \
# 0     0     536365 2010-12-01 08:26:00    85123A
# 1     1     536373 2010-12-01 09:02:00    85123A
# 2     2     536375 2010-12-01 09:32:00    85123A
# 3     3     536390 2010-12-01 10:19:00    85123A
# 4     4     536394 2010-12-01 10:39:00    85123A
#
#                           description  quantity  unitprice  revenue  \
# 0  CREAM HANGING HEART T-LIGHT HOLDER        18       2.55     15.3
# 1  CREAM HANGING HEART T-LIGHT HOLDER        18       2.55     15.3
# 2  CREAM HANGING HEART T-LIGHT HOLDER        18       2.55     15.3
# 3  CREAM HANGING HEART T-LIGHT HOLDER        76       2.55    163.2
# 4  CREAM HANGING HEART T-LIGHT HOLDER        44       2.55     81.6
#
#    customerid         country  null      nueva    nueva_2
# 0       17850  United Kingdom   NaN   7.058824   7.058824
# 1       17850  United Kingdom   1.0   7.058824   7.058824
# 2       17850  United Kingdom   NaN   7.058824   7.058824
# 3       17511  United Kingdom   3.0  29.803922  29.803922
# 4       13408  United Kingdom   NaN  17.254902  17.254902

# %% [markdown]
# ### Json Normalize, Explode

# %%
df_json=pd.read_json('../data/companies.json', lines=True)

df_json.head()
# Out:
#                                     _id       name permalink  \
# 0  {'$oid': '52cdef7c4bab8bd675297d8a'}   Wetpaint      abc2
# 1  {'$oid': '52cdef7c4bab8bd675297d8b'}  AdventNet      abc3
# 2  {'$oid': '52cdef7c4bab8bd675297d8c'}       Zoho      abc4
# 3  {'$oid': '52cdef7c4bab8bd675297d8d'}       Digg      digg
# 4  {'$oid': '52cdef7c4bab8bd675297d8e'}   Facebook  facebook
#
#                                 crunchbase_url             homepage_url  \
# 0   http://www.crunchbase.com/company/wetpaint  http://wetpaint-inc.com
# 1  http://www.crunchbase.com/company/adventnet     http://adventnet.com
# 2       http://www.crunchbase.com/company/zoho          http://zoho.com
# 3       http://www.crunchbase.com/company/digg      http://www.digg.com
# 4   http://www.crunchbase.com/company/facebook      http://facebook.com
#
#                       blog_url                      blog_feed_url  \
# 0  http://digitalquarters.net/   http://digitalquarters.net/feed/
# 1
# 2       http://blogs.zoho.com/         http://blogs.zoho.com/feed
# 3        http://blog.digg.com/    http://blog.digg.com/?feed=rss2
# 4     http://blog.facebook.com  http://blog.facebook.com/atom.php
#
#   twitter_username category_code  number_of_employees  ...  \
# 0  BachelrWetpaint           web                 47.0  ...
# 1     manageengine    enterprise                600.0  ...
# 2             zoho      software               1600.0  ...
# 3             digg          news                 60.0  ...
# 4         facebook        social               5299.0  ...
#
#                                              offices  \
# 0  [{'description': '', 'address1': '710 - 2nd Av...
# 1  [{'description': 'Headquarters', 'address1': '...
# 2  [{'description': 'Headquarters', 'address1': '...
# 3  [{'description': None, 'address1': '135 Missis...
# 4  [{'description': 'Headquarters', 'address1': '...
#
#                                           milestones  \
# 0  [{'id': 5869, 'description': 'Wetpaint named i...
# 1                                                 []
# 2  [{'id': 388, 'description': 'Zoho Reaches 2 Mi...
# 3  [{'id': 9588, 'description': 'Another Digg Exe...
# 4  [{'id': 108, 'description': 'Facebook adds com...
#
#                                         video_embeds  \
# 0                                                 []
# 1                                                 []
# 2  [{'embed_code': '<object width="430" height="2...
# 3  [{'embed_code': '<embed src="http://blip.tv/pl...
# 4                                                 []
#
#                                          screenshots  \
# 0  [{'available_sizes': [[[150, 86], 'assets/imag...
# 1  [{'available_sizes': [[[150, 94], 'assets/imag...
# 2                                                 []
# 3  [{'available_sizes': [[[117, 150], 'assets/ima...
# 4  [{'available_sizes': [[[150, 68], 'assets/imag...
#
#                                       external_links partners  \
# 0  [{'external_url': 'http://www.geekwire.com/201...       []
# 1                                                 []       []
# 2  [{'external_url': 'http://www.online-tech-tips...       []
# 3  [{'external_url': 'http://www.sociableblog.com...       []
# 4  [{'external_url': 'http://latimesblogs.latimes...       []
#
#   deadpooled_month deadpooled_day deadpooled_url  \
# 0              NaN            NaN            NaN
# 1              NaN            NaN            NaN
# 2              NaN            NaN            NaN
# 3              NaN            NaN           None
# 4              NaN            NaN
#
#                                                  ipo
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                               None
# 4  {'valuation_amount': 104000000000, 'valuation_...
#
# [5 rows x 42 columns]

# %%
pd.json_normalize(df_json._id)
# Out:
#                            $oid
# 0      52cdef7c4bab8bd675297d8a
# 1      52cdef7c4bab8bd675297d8b
# 2      52cdef7c4bab8bd675297d8c
# 3      52cdef7c4bab8bd675297d8d
# 4      52cdef7c4bab8bd675297d8e
# ...                         ...
# 18796  52cdef7f4bab8bd67529c6f6
# 18797  52cdef7f4bab8bd67529c6f7
# 18798  52cdef7f4bab8bd67529c6f8
# 18799  52cdef7f4bab8bd67529c6f9
# 18800  52cdef7f4bab8bd67529c6fa
#
# [18801 rows x 1 columns]

# %%
pd.json_normalize(df_json.ipo).head()
# Out:
#    valuation_amount valuation_currency_code  pub_year  pub_month  pub_day  \
# 0               NaN                     NaN       NaN        NaN      NaN
# 1               NaN                     NaN       NaN        NaN      NaN
# 2               NaN                     NaN       NaN        NaN      NaN
# 3               NaN                     NaN       NaN        NaN      NaN
# 4      1.040000e+11                     USD    2012.0        5.0     18.0
#
#   stock_symbol
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4    NASDAQ:FB

# %%
data = [
    {"id": 1, "name": {"first": "Coleen", "last": {0:"Volk"}}},
    {"name": {"given": "Mark", "family": "Regner"}},
    {"id": 2, "name": "Faye Raker"},
]

data
# Out:
# [{'id': 1, 'name': {'first': 'Coleen', 'last': {0: 'Volk'}}},
#  {'name': {'given': 'Mark', 'family': 'Regner'}},
#  {'id': 2, 'name': 'Faye Raker'}]

# %%
pd.DataFrame(data)
# Out:
#     id                                      name
# 0  1.0  {'first': 'Coleen', 'last': {0: 'Volk'}}
# 1  NaN     {'given': 'Mark', 'family': 'Regner'}
# 2  2.0                                Faye Raker

# %%
pd.json_normalize(data)
# Out:
#     id name.first name.last.0 name.given name.family        name
# 0  1.0     Coleen        Volk        NaN         NaN         NaN
# 1  NaN        NaN         NaN       Mark      Regner         NaN
# 2  2.0        NaN         NaN        NaN         NaN  Faye Raker

# %%
data=[[12, 3, 45], [432, 543, 5]]

pd.DataFrame([data])
# Out:
#              0              1
# 0  [12, 3, 45]  [432, 543, 5]

# %%
pd.DataFrame([data]).explode(0)
# Out:
#     0              1
# 0  12  [432, 543, 5]
# 0   3  [432, 543, 5]
# 0  45  [432, 543, 5]

# %%
pd.DataFrame([data]).explode(0).explode(1).reset_index()
# Out:
#    index   0    1
# 0      0  12  432
# 1      0  12  543
# 2      0  12    5
# 3      0   3  432
# 4      0   3  543
# 5      0   3    5
# 6      0  45  432
# 7      0  45  543
# 8      0  45    5

# %% [markdown]
# ### Unión de dataframes

# %%
# concatenacion, pegar con loctite

# uno debajo del otro, las columnas tienen que coindicir en nombre

pd.concat([df, df]).head()
# Out:
#   index  invoiceno         invoicedate stockcode  \
# 0     0     536365 2010-12-01 08:26:00    85123A
# 1     1     536373 2010-12-01 09:02:00    85123A
# 2     2     536375 2010-12-01 09:32:00    85123A
# 3     3     536390 2010-12-01 10:19:00    85123A
# 4     4     536394 2010-12-01 10:39:00    85123A
#
#                           description  quantity  unitprice  revenue  \
# 0  CREAM HANGING HEART T-LIGHT HOLDER        18       2.55     15.3
# 1  CREAM HANGING HEART T-LIGHT HOLDER        18       2.55     15.3
# 2  CREAM HANGING HEART T-LIGHT HOLDER        18       2.55     15.3
# 3  CREAM HANGING HEART T-LIGHT HOLDER        76       2.55    163.2
# 4  CREAM HANGING HEART T-LIGHT HOLDER        44       2.55     81.6
#
#    customerid         country  null      nueva    nueva_2
# 0       17850  United Kingdom   NaN   7.058824   7.058824
# 1       17850  United Kingdom   1.0   7.058824   7.058824
# 2       17850  United Kingdom   NaN   7.058824   7.058824
# 3       17511  United Kingdom   3.0  29.803922  29.803922
# 4       13408  United Kingdom   NaN  17.254902  17.254902

# %%
df.shape, pd.concat([df, df]).shape
# Out:
# ((396034, 13), (792068, 13))

# %%
pd.concat([df, df], axis=0).shape  # axis=0 por defecto
# Out:
# (792068, 13)

# %%
pd.concat([df, df], axis=1).shape # uno al lado del otro
# Out:
# (396034, 26)

# %%
# join

uno=pd.DataFrame({'key': ['K0', 'K1', 'K2', 'K3', 'K4', 'K5'],
                   'A': ['A0', 'A1', 'A2', 'A3', 'A4', 'A5']})


otro=pd.DataFrame({'key': ['K0', 'K1', 'K2', 'K8'],
                      'B': ['B0', 'B1', 'B2', 'B8']})

# %%
uno
# Out:
#   key   A
# 0  K0  A0
# 1  K1  A1
# 2  K2  A2
# 3  K3  A3
# 4  K4  A4
# 5  K5  A5

# %%
otro
# Out:
#   key   B
# 0  K0  B0
# 1  K1  B1
# 2  K2  B2
# 3  K8  B8

# %%
uno.set_index('key')
# Out:
#       A
# key
# K0   A0
# K1   A1
# K2   A2
# K3   A3
# K4   A4
# K5   A5

# %%
uno.set_index('key').join(otro.set_index('key'))
# Out:
#       A    B
# key
# K0   A0   B0
# K1   A1   B1
# K2   A2   B2
# K3   A3  NaN
# K4   A4  NaN
# K5   A5  NaN

# %%
otro.set_index('key').join(uno.set_index('key'))
# Out:
#       B    A
# key
# K0   B0   A0
# K1   B1   A1
# K2   B2   A2
# K8   B8  NaN

# %%
uno.join(otro.set_index('key'), on='key')   # sobre una columna
# Out:
#   key   A    B
# 0  K0  A0   B0
# 1  K1  A1   B1
# 2  K2  A2   B2
# 3  K3  A3  NaN
# 4  K4  A4  NaN
# 5  K5  A5  NaN

# %%
uno.join(otro.set_index('key'), on='key', how='right')
# Out:
#     key    A   B
# 0.0  K0   A0  B0
# 1.0  K1   A1  B1
# 2.0  K2   A2  B2
# NaN  K8  NaN  B8

# %%
# merge

df1=pd.DataFrame({'lkey': ['foo', 'bar', 'baz', 'foo'],
                    'value': [1, 2, 3, 5]})


df2=pd.DataFrame({'rkey': ['foo', 'bar', 'baz', 'foo'],
                    'value': [5, 6, 7, 8]})

# %%
df1
# Out:
#   lkey  value
# 0  foo      1
# 1  bar      2
# 2  baz      3
# 3  foo      5

# %%
df2
# Out:
#   rkey  value
# 0  foo      5
# 1  bar      6
# 2  baz      7
# 3  foo      8

# %%
df1.merge(df2, left_on='lkey', right_on='rkey', suffixes=('_izq', '_dcha'))
# Out:
#   lkey  value_izq rkey  value_dcha
# 0  foo          1  foo           5
# 1  foo          1  foo           8
# 2  foo          5  foo           5
# 3  foo          5  foo           8
# 4  bar          2  bar           6
# 5  baz          3  baz           7

# %%
uno.merge(otro, left_on='key', right_on='key', suffixes=('_izq', '_dcha'))
# Out:
#   key   A   B
# 0  K0  A0  B0
# 1  K1  A1  B1
# 2  K2  A2  B2

# %% [markdown]
# ### Eval y query

# %%
df1=pd.DataFrame(np.random.random((10, 3)), columns=['a', 'b', 'c'])
df2=pd.DataFrame(np.random.random((10, 3)), columns=['a', 'b', 'c'])

# %%
df1
# Out:
#           a         b         c
# 0  0.162662  0.977014  0.929233
# 1  0.922782  0.234955  0.461236
# 2  0.351475  0.518116  0.699780
# 3  0.648321  0.393759  0.573459
# 4  0.862158  0.769242  0.143437
# 5  0.494618  0.598395  0.212884
# 6  0.668912  0.609358  0.429824
# 7  0.987954  0.170936  0.595469
# 8  0.815553  0.478674  0.464061
# 9  0.841636  0.780726  0.802306

# %%
df2
# Out:
#           a         b         c
# 0  0.491788  0.786545  0.773687
# 1  0.593010  0.908221  0.371547
# 2  0.264861  0.386555  0.595149
# 3  0.519266  0.167286  0.889393
# 4  0.935598  0.465946  0.961861
# 5  0.143832  0.756627  0.179127
# 6  0.823632  0.148212  0.247737
# 7  0.825175  0.617155  0.600540
# 8  0.174896  0.808104  0.978071
# 9  0.368476  0.280031  0.412770

# %%
pd.eval('df1 < df2')
# Out:
#        a      b      c
# 0   True  False  False
# 1  False   True  False
# 2  False  False  False
# 3  False  False   True
# 4   True  False   True
# 5  False   True  False
# 6   True  False  False
# 7  False   True   True
# 8  False   True   True
# 9  False  False  False

# %%
df1[df1.eval('b>0.5')]
# Out:
#           a         b         c
# 0  0.162662  0.977014  0.929233
# 2  0.351475  0.518116  0.699780
# 4  0.862158  0.769242  0.143437
# 5  0.494618  0.598395  0.212884
# 6  0.668912  0.609358  0.429824
# 9  0.841636  0.780726  0.802306

# %%
df1[df1.b>0.5]
# Out:
#           a         b         c
# 0  0.162662  0.977014  0.929233
# 2  0.351475  0.518116  0.699780
# 4  0.862158  0.769242  0.143437
# 5  0.494618  0.598395  0.212884
# 6  0.668912  0.609358  0.429824
# 9  0.841636  0.780726  0.802306

# %%
df1.query(' b > 0.5')
# Out:
#           a         b         c
# 0  0.162662  0.977014  0.929233
# 2  0.351475  0.518116  0.699780
# 4  0.862158  0.769242  0.143437
# 5  0.494618  0.598395  0.212884
# 6  0.668912  0.609358  0.429824
# 9  0.841636  0.780726  0.802306

# %%
df1.query(' b > 0.5 & a > 0.3')
# Out:
#           a         b         c
# 2  0.351475  0.518116  0.699780
# 4  0.862158  0.769242  0.143437
# 5  0.494618  0.598395  0.212884
# 6  0.668912  0.609358  0.429824
# 9  0.841636  0.780726  0.802306

# %%
df1.query(' b > 0.5 | a > 0.3')
# Out:
#           a         b         c
# 0  0.162662  0.977014  0.929233
# 1  0.922782  0.234955  0.461236
# 2  0.351475  0.518116  0.699780
# 3  0.648321  0.393759  0.573459
# 4  0.862158  0.769242  0.143437
# 5  0.494618  0.598395  0.212884
# 6  0.668912  0.609358  0.429824
# 7  0.987954  0.170936  0.595469
# 8  0.815553  0.478674  0.464061
# 9  0.841636  0.780726  0.802306

# %% [markdown]
# ### lookup

# %%
seasons=pd.DataFrame(np.random.random((10, 4)), 
                     columns=['winter', 'spring', 'summer', 'autumn'])
seasons
# Out:
#      winter    spring    summer    autumn
# 0  0.087849  0.841427  0.530300  0.034068
# 1  0.120697  0.126477  0.672101  0.099805
# 2  0.554869  0.682286  0.357219  0.354101
# 3  0.576649  0.642751  0.466981  0.769378
# 4  0.386660  0.509389  0.370715  0.157431
# 5  0.314747  0.595139  0.436110  0.586141
# 6  0.608526  0.177613  0.529094  0.765681
# 7  0.942575  0.464682  0.446408  0.539064
# 8  0.446987  0.398452  0.897074  0.683122
# 9  0.877856  0.050980  0.966765  0.868397

# %%
look_lst=['summer', 'winter','spring', 
          'winter', 'summer', 'autumn',
          'autumn', 'summer', 'autumn', 
          'spring']

# %%
seasons['look'] = seasons.lookup(seasons.index, look_lst)

seasons
# Out:
#      winter    spring    summer    autumn      look
# 0  0.087849  0.841427  0.530300  0.034068  0.530300
# 1  0.120697  0.126477  0.672101  0.099805  0.120697
# 2  0.554869  0.682286  0.357219  0.354101  0.682286
# 3  0.576649  0.642751  0.466981  0.769378  0.576649
# 4  0.386660  0.509389  0.370715  0.157431  0.370715
# 5  0.314747  0.595139  0.436110  0.586141  0.586141
# 6  0.608526  0.177613  0.529094  0.765681  0.765681
# 7  0.942575  0.464682  0.446408  0.539064  0.446408
# 8  0.446987  0.398452  0.897074  0.683122  0.683122
# 9  0.877856  0.050980  0.966765  0.868397  0.050980

# %%
print(look_lst)
# Out:
# ['summer', 'winter', 'spring', 'winter', 'summer', 'autumn', 'autumn', 'summer', 'autumn', 'spring']

# %% [markdown]
# ### get

# %%
seasons.get(seasons.spring>0.5)
# Out:
#      winter    spring    summer    autumn      look
# 0  0.087849  0.841427  0.530300  0.034068  0.530300
# 2  0.554869  0.682286  0.357219  0.354101  0.682286
# 3  0.576649  0.642751  0.466981  0.769378  0.576649
# 4  0.386660  0.509389  0.370715  0.157431  0.370715
# 5  0.314747  0.595139  0.436110  0.586141  0.586141

# %%
seasons[seasons.spring>0.5]
# Out:
#      winter    spring    summer    autumn      look
# 0  0.087849  0.841427  0.530300  0.034068  0.530300
# 2  0.554869  0.682286  0.357219  0.354101  0.682286
# 3  0.576649  0.642751  0.466981  0.769378  0.576649
# 4  0.386660  0.509389  0.370715  0.157431  0.370715
# 5  0.314747  0.595139  0.436110  0.586141  0.586141

# %%
seasons.get((seasons.spring>0.5) & (seasons.summer>0.4))
# Out:
#      winter    spring    summer    autumn      look
# 0  0.087849  0.841427  0.530300  0.034068  0.530300
# 3  0.576649  0.642751  0.466981  0.769378  0.576649
# 5  0.314747  0.595139  0.436110  0.586141  0.586141

# %% [markdown]
# ### index y reindex

# %%
seasons.index
# Out:
# RangeIndex(start=0, stop=10, step=1)

# %%
seasons.index=pd.RangeIndex(0, 20, 2)

seasons
# Out:
#       winter    spring    summer    autumn      look
# 0   0.087849  0.841427  0.530300  0.034068  0.530300
# 2   0.120697  0.126477  0.672101  0.099805  0.120697
# 4   0.554869  0.682286  0.357219  0.354101  0.682286
# 6   0.576649  0.642751  0.466981  0.769378  0.576649
# 8   0.386660  0.509389  0.370715  0.157431  0.370715
# 10  0.314747  0.595139  0.436110  0.586141  0.586141
# 12  0.608526  0.177613  0.529094  0.765681  0.765681
# 14  0.942575  0.464682  0.446408  0.539064  0.446408
# 16  0.446987  0.398452  0.897074  0.683122  0.683122
# 18  0.877856  0.050980  0.966765  0.868397  0.050980

# %%
seasons.index=range(10)

seasons
# Out:
#      winter    spring    summer    autumn      look
# 0  0.087849  0.841427  0.530300  0.034068  0.530300
# 1  0.120697  0.126477  0.672101  0.099805  0.120697
# 2  0.554869  0.682286  0.357219  0.354101  0.682286
# 3  0.576649  0.642751  0.466981  0.769378  0.576649
# 4  0.386660  0.509389  0.370715  0.157431  0.370715
# 5  0.314747  0.595139  0.436110  0.586141  0.586141
# 6  0.608526  0.177613  0.529094  0.765681  0.765681
# 7  0.942575  0.464682  0.446408  0.539064  0.446408
# 8  0.446987  0.398452  0.897074  0.683122  0.683122
# 9  0.877856  0.050980  0.966765  0.868397  0.050980

# %%
seasons.index=seasons.spring

seasons
# Out:
#             winter    spring    summer    autumn      look
# spring
# 0.841427  0.087849  0.841427  0.530300  0.034068  0.530300
# 0.126477  0.120697  0.126477  0.672101  0.099805  0.120697
# 0.682286  0.554869  0.682286  0.357219  0.354101  0.682286
# 0.642751  0.576649  0.642751  0.466981  0.769378  0.576649
# 0.509389  0.386660  0.509389  0.370715  0.157431  0.370715
# 0.595139  0.314747  0.595139  0.436110  0.586141  0.586141
# 0.177613  0.608526  0.177613  0.529094  0.765681  0.765681
# 0.464682  0.942575  0.464682  0.446408  0.539064  0.446408
# 0.398452  0.446987  0.398452  0.897074  0.683122  0.683122
# 0.050980  0.877856  0.050980  0.966765  0.868397  0.050980

# %%
seasons.set_index('winter', inplace=True)

# %%
seasons
# Out:
#             spring    summer    autumn      look
# winter
# 0.087849  0.841427  0.530300  0.034068  0.530300
# 0.120697  0.126477  0.672101  0.099805  0.120697
# 0.554869  0.682286  0.357219  0.354101  0.682286
# 0.576649  0.642751  0.466981  0.769378  0.576649
# 0.386660  0.509389  0.370715  0.157431  0.370715
# 0.314747  0.595139  0.436110  0.586141  0.586141
# 0.608526  0.177613  0.529094  0.765681  0.765681
# 0.942575  0.464682  0.446408  0.539064  0.446408
# 0.446987  0.398452  0.897074  0.683122  0.683122
# 0.877856  0.050980  0.966765  0.868397  0.050980

# %%
seasons.reset_index(inplace=True)

# %%
seasons
# Out:
#      winter    spring    summer    autumn      look
# 0  0.087849  0.841427  0.530300  0.034068  0.530300
# 1  0.120697  0.126477  0.672101  0.099805  0.120697
# 2  0.554869  0.682286  0.357219  0.354101  0.682286
# 3  0.576649  0.642751  0.466981  0.769378  0.576649
# 4  0.386660  0.509389  0.370715  0.157431  0.370715
# 5  0.314747  0.595139  0.436110  0.586141  0.586141
# 6  0.608526  0.177613  0.529094  0.765681  0.765681
# 7  0.942575  0.464682  0.446408  0.539064  0.446408
# 8  0.446987  0.398452  0.897074  0.683122  0.683122
# 9  0.877856  0.050980  0.966765  0.868397  0.050980

# %% [markdown]
# ### Multi index

# %%
seasons.set_index(['summer', 'winter'], inplace=True)

seasons
# Out:
#                      spring    autumn      look
# summer   winter
# 0.530300 0.087849  0.841427  0.034068  0.530300
# 0.672101 0.120697  0.126477  0.099805  0.120697
# 0.357219 0.554869  0.682286  0.354101  0.682286
# 0.466981 0.576649  0.642751  0.769378  0.576649
# 0.370715 0.386660  0.509389  0.157431  0.370715
# 0.436110 0.314747  0.595139  0.586141  0.586141
# 0.529094 0.608526  0.177613  0.765681  0.765681
# 0.446408 0.942575  0.464682  0.539064  0.446408
# 0.897074 0.446987  0.398452  0.683122  0.683122
# 0.966765 0.877856  0.050980  0.868397  0.050980

# %%
seasons.index
# Out:
# MultiIndex([( 0.5303003052973329,  0.0878491476578227),
#             ( 0.6721012445327321, 0.12069691708720498),
#             (  0.357219024264802,   0.554868607564248),
#             ( 0.4669808261305337,  0.5766487464822366),
#             (0.37071529776964474,  0.3866604139889037),
#             ( 0.4361095834834844,  0.3147465800919006),
#             (  0.529093600558793,  0.6085263537337369),
#             ( 0.4464079597086057,  0.9425747563721567),
#             (  0.897073566647299, 0.44698729620087085),
#             ( 0.9667646332051762,  0.8778555150719958)],
#            names=['summer', 'winter'])

# %%
seasons.index[0]
# Out:
# (0.5303003052973329, 0.0878491476578227)

# %%
seasons.loc[(0.5303003052973329, 0.0878491476578227)]
# Out:
# spring    0.841427
# autumn    0.034068
# look      0.530300
# Name: (0.5303003052973329, 0.0878491476578227), dtype: float64

# %%
seasons.iloc[0]
# Out:
# spring    0.841427
# autumn    0.034068
# look      0.530300
# Name: (0.5303003052973329, 0.0878491476578227), dtype: float64

# %% [markdown]
# ### Exportar datos

# %%
# exporta a csv sin indice

df.to_csv('../data/retail.csv', index=False)

# %%
# exporta a excel sin indice

df.to_excel('../data/retail.xlsx', index=False)

# %%
# exporta a json, nombre de columna como key

df.to_json('../data/retail.json', orient='records')

# %% [markdown]
# ### Métodos habituales de pandas

# %% [markdown]
# ```python
# df.head()                     # printea la cabeza, por defecto 5 filas
# df.tail()                     # pritea la cola, por defecto 5 filas
# df.describe()                 # descripcion estadistica
# df.info()                     # informacion del df
# df.info(memory_usage='deep')
# df.columns                    # muestra columna
# df.index                      # muestra indice
# df.dtypes                     # muestra tipos de datos de las columnas
# df.plot()                     # hace un grafico
# df.hist()                     # hace un histograma
# df.col.value_counts()         # cuenta los valores unicos de una columna
# df.col.unique()               # muestra valores unicos de una columna
# df.copy()                     # copia el df
# df.drop()                     # elimina columnas o filas (axis=0,1)
# df.dropna()                   # elimina nulos
# df.fillna()                   # rellena nulos
# df.shape                      # dimensiones del df
# df._get_numeric_data()        # selecciona columnas numericas
# df.rename()                   # renombre columnas
# df.str.replace()              # reemplaza columnas de strings
# df.astype(dtype='float32')    # cambia el tipo de dato
# df.iloc[]                     # localiza por indice
# df.loc[]                      # localiza por elemento
# df.transpose()                # transpone el df
# df.T
# df.sample(n, frac)            # muestra del df
# df.col.sum()                  # suma de una columna
# df.col.max()                  # maximo de una columna
# df.col.min()                  # minimo de una columna
# df[col]                       # selecciona columna
# df.col
# df.isnull()                   # valores nulos
# df.isna()
# df.notna()                    # valores no nulos
# df.drop_duplicates()          # eliminar duplicados
# df.reset_index(inplace=True)  # resetea el indice y sobreescribe
# ```
