# %% [markdown]
# # 4.2 - Office finder mongo version
#
# #### Encontramos tu oficina

# %%
# %pip install folium
# Out:
# Requirement already satisfied: folium in /opt/homebrew/Caskroom/miniconda/base/envs/clase/lib/python3.9/site-packages (0.14.0)
# Requirement already satisfied: numpy in /opt/homebrew/Caskroom/miniconda/base/envs/clase/lib/python3.9/site-packages (from folium) (1.23.5)
# Requirement already satisfied: branca>=0.6.0 in /opt/homebrew/Caskroom/miniconda/base/envs/clase/lib/python3.9/site-packages (from folium) (0.6.0)
# Requirement already satisfied: requests in /opt/homebrew/Caskroom/miniconda/base/envs/clase/lib/python3.9/site-packages (from folium) (2.28.1)
# Requirement already satisfied: jinja2>=2.9 in /opt/homebrew/Caskroom/miniconda/base/envs/clase/lib/python3.9/site-packages (from folium) (3.1.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/homebrew/Caskroom/miniconda/base/envs/clase/lib/python3.9/site-packages (from jinja2>=2.9->folium) (2.1.1)
# Requirement already satisfied: charset-normalizer<3,>=2 in /opt/homebrew/Caskroom/miniconda/base/envs/clase/lib/python3.9/site-packages (from requests->folium) (2.1.1)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/homebrew/Caskroom/miniconda/base/envs/clase/lib/python3.9/site-packages (from requests->folium) (2022.12.7)
# Requirement already satisfied: idna<4,>=2.5 in /opt/homebrew/Caskroom/miniconda/base/envs/clase/lib/python3.9/site-packages (from requests->folium) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /opt/homebrew/Caskroom/miniconda/base/envs/clase/lib/python3.9/site-packages (from requests->folium) (1.26.13)
# WARNING: Error parsing requirements for pyarrow: [Errno 21] Is a directory: '/opt/homebrew/Caskroom/miniconda/base/envs/clase/lib/python3.9/site-packages/pyarrow-10.0.1.dist-info/METADATA'
# Note: you may need to restart the kernel to use updated packages.

# %%
# librerias

from pymongo import MongoClient

import pandas as pd

import folium   # esto es para hacer mapas

import re

# %%
# conexion a mongo

cliente=MongoClient()

db=cliente.companies

colec=db.companies

# %%
query={'$and': [
    
    {'$or': [{'category_code': 'games_video'}, 
             {'category_code': 'web'},
             {'category_code': 'ecommerce'}]},
    
    {'founded_year': {'$gte': 1999}},
    {'deadpooled_year': None},
    {'number_of_employees': {'$ne': None}},
    {'number_of_employees': {'$ne': 0}},
    {'total_money_raised': {'$ne': None}}
    
]}


filtro={'name': 1, '_id':0, 'offices.latitude': 1, 'offices.longitude': 1,
         'founded_year': 1, 'category_code':1, 'number_of_employees':1,
         'total_money_raised':1}




data=pd.json_normalize(data=colec.find(query, filtro), 
                       record_path='offices', 
                       meta=['category_code', 'name', 'number_of_employees',
                            'founded_year', 'total_money_raised'])


data.head()
# Out:
#     latitude   longitude category_code    name number_of_employees  \
# 0  34.090368 -118.393064           web    Geni                  18
# 1  37.387845 -122.055197           web   Plaxo                  50
# 2  34.017606 -118.487267           web  Mahalo                  40
# 3  37.788482 -122.409173   games_video    Kyte                  40
# 4  40.726040  -73.995722           web  Meetup                  75
#
#   founded_year total_money_raised
# 0         2006             $16.5M
# 1         2002             $28.3M
# 2         2007               $21M
# 3         2006             $23.4M
# 4         2002             $18.3M

# %%
data.insert(2, 'geo_loc', pd.Series(list(range(len(data)))))

# %%
# aqui relleno la columna con una lista de longitud y latitud
data['geo_loc']=data.apply(lambda x: [x['longitude'], x['latitude']], axis=1)


data.head()
# Out:
#     latitude   longitude                   geo_loc category_code    name  \
# 0  34.090368 -118.393064  [-118.393064, 34.090368]           web    Geni
# 1  37.387845 -122.055197  [-122.055197, 37.387845]           web   Plaxo
# 2  34.017606 -118.487267  [-118.487267, 34.017606]           web  Mahalo
# 3  37.788482 -122.409173  [-122.409173, 37.788482]   games_video    Kyte
# 4  40.726040  -73.995722    [-73.995722, 40.72604]           web  Meetup
#
#   number_of_employees founded_year total_money_raised
# 0                  18         2006             $16.5M
# 1                  50         2002             $28.3M
# 2                  40         2007               $21M
# 3                  40         2006             $23.4M
# 4                  75         2002             $18.3M

# %%
data=data.dropna()

# %%
data.tail()
# Out:
#        latitude   longitude                    geo_loc category_code  \
# 2257  29.735462  -95.413243    [-95.413243, 29.735462]   games_video
# 2258  40.756054  -73.986951    [-73.986951, 40.756054]           web
# 2260  59.617364   16.559539    [16.5595393, 59.617364]           web
# 2261  49.282455 -123.109217  [-123.109217, 49.2824551]   games_video
# 2262  38.752367   -9.146221   [-9.1462209, 38.7523672]   games_video
#
#               name number_of_employees founded_year total_money_raised
# 2257    Fictionaut                   2         2008                 $0
# 2258  Conversition                  10         2008                 $0
# 2260    Gastrogate                  12         1999                 $0
# 2261    Tiny Speck                  45         2009             $17.2M
# 2262   My TV Shows                   2         2007                 $0

# %%
def exchange(col):
    
    res=[]
    
    number=1
    
    symbol=1
    
    for e in col:
        
        if e[-1]=='k': number=1e3
        elif e[-1]=='M': number=1e6
        elif e[-1]=='B': number=1e9
            
        if e[0]=='£': symbol=1.3
        elif e[0]=='€' : symbol=1.12
        
        n_col=re.findall('[0-9.]+', e)[0]

        
        res.append(int(float(n_col) * number * symbol))
        
    return res

# %%
exchange(['£28.3M'])
# Out:
# [36790000]

# %%
data['n_total_money']=exchange(data.total_money_raised)

data.head()
# Out:
#     latitude   longitude                   geo_loc category_code    name  \
# 0  34.090368 -118.393064  [-118.393064, 34.090368]           web    Geni
# 1  37.387845 -122.055197  [-122.055197, 37.387845]           web   Plaxo
# 2  34.017606 -118.487267  [-118.487267, 34.017606]           web  Mahalo
# 3  37.788482 -122.409173  [-122.409173, 37.788482]   games_video    Kyte
# 4  40.726040  -73.995722    [-73.995722, 40.72604]           web  Meetup
#
#   number_of_employees founded_year total_money_raised  n_total_money
# 0                  18         2006             $16.5M       16500000
# 1                  50         2002             $28.3M       28300000
# 2                  40         2007               $21M       21000000
# 3                  40         2006             $23.4M       23400000
# 4                  75         2002             $18.3M       18300000

# %%
data.reset_index(drop=True, inplace=True)

# %%
def classifying(date, employees):
    
    company_class=[]
    
    for i in range(len(date)):
        
        if date[i]>=2008 and employees[i]<100:
            company_class.append('StartUp')
        else:
            company_class.append('BigCorp')
            
    
    return company_class

# %%
data['company_class']=classifying(data.founded_year, data.number_of_employees)

# %%
data.head()
# Out:
#     latitude   longitude                   geo_loc category_code    name  \
# 0  34.090368 -118.393064  [-118.393064, 34.090368]           web    Geni
# 1  37.387845 -122.055197  [-122.055197, 37.387845]           web   Plaxo
# 2  34.017606 -118.487267  [-118.487267, 34.017606]           web  Mahalo
# 3  37.788482 -122.409173  [-122.409173, 37.788482]   games_video    Kyte
# 4  40.726040  -73.995722    [-73.995722, 40.72604]           web  Meetup
#
#   number_of_employees founded_year total_money_raised  n_total_money  \
# 0                  18         2006             $16.5M       16500000
# 1                  50         2002             $28.3M       28300000
# 2                  40         2007               $21M       21000000
# 3                  40         2006             $23.4M       23400000
# 4                  75         2002             $18.3M       18300000
#
#   company_class
# 0       BigCorp
# 1       BigCorp
# 2       BigCorp
# 3       BigCorp
# 4       BigCorp

# %%
# insertar en mongo

#df.to_json('geoloc.json', orient='records', lines=True)

# %%
db.geoloc.insert_many(data.to_dict('records'))

# %%
db.geoloc.create_index([('geo_loc', '2dsphere')])
# Out:
# 'geo_loc_2dsphere'

# %%
# geolocalizacion

def geoquery(df):
    
    list_money_mean=[]
    
    sb_ratio=[]
    
    n_companies=[]
    
    for i in range(len(df)):
        
        q=list(db.geoloc.find({'geo_loc': {'$near': {'$geometry': {
                                     
                                'type': 'Point',
                                'coordinates': df.geo_loc[i]},
                                
                                '$maxDistance': 1000}}}))
        
        
        long_list=len(q)
        
        # media de dinero
        money_mean=sum([q[j]['n_total_money'] for j in range(long_list)]) / long_list
        
        list_money_mean.append(money_mean)
        
        # startup-bigcorp
        
        big=sum(q[k]['company_class'].count('BigCorp') 
                if q[k]['company_class'].count('BigCorp')!=0 
                else 1 for k in range(long_list))
        
        start=sum(q[k]['company_class'].count('StartUp')  for k in range(long_list))
        
        # si sb_ratio=1 entonces big=start, si sb_ratio<1 hay más big, si sb_ratio>1 hay mas start
        sb_ratio.append(start/big)
        
        
        # nº compañias
        n_companies.append(long_list)
        
        
    df['around_companies']=n_companies
    
    df['sb_ratio']=sb_ratio
    
    df['money_density']=list_money_mean
    
    return df

# %%
data=geoquery(data)

data.head()
# Out:
#     latitude   longitude                   geo_loc category_code    name  \
# 0  34.090368 -118.393064  [-118.393064, 34.090368]           web    Geni
# 1  37.387845 -122.055197  [-122.055197, 37.387845]           web   Plaxo
# 2  34.017606 -118.487267  [-118.487267, 34.017606]           web  Mahalo
# 3  37.788482 -122.409173  [-122.409173, 37.788482]   games_video    Kyte
# 4  40.726040  -73.995722    [-73.995722, 40.72604]           web  Meetup
#
#   number_of_employees founded_year total_money_raised  n_total_money  \
# 0                  18         2006             $16.5M       16500000
# 1                  50         2002             $28.3M       28300000
# 2                  40         2007               $21M       21000000
# 3                  40         2006             $23.4M       23400000
# 4                  75         2002             $18.3M       18300000
#
#   company_class  around_companies  sb_ratio  money_density
# 0       BigCorp                 1  0.000000   1.650000e+07
# 1       BigCorp                 2  0.000000   1.415000e+07
# 2       BigCorp                 3  0.333333   8.333333e+06
# 3       BigCorp                24  0.375000   8.157333e+06
# 4       BigCorp                16  0.187500   4.370625e+06

# %%
def geomap(df, zoom_start=1.5):

    df.index=range(len(df)) 

    mapa=folium.Map(location=[0, 0],
                    tiles='openstreetmap', 
                    zoom_start=zoom_start)
    
    
    for i in range(1, len(df)):

        folium.CircleMarker([float(df.latitude[i]), float(df.longitude[i])], 
                            popup=str(df.name[i]), 
                            radius=1, 
                            icon=folium.Icon()).add_to(mapa)

    #mapa.save('images/geomap.html')
    
    return mapa

# %%
print('oficinas')

mapa=geomap(data.loc[:1500])

mapa
# Out:
# oficinas
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_d80ac41c6acb8f97bef5a37ffa0a659f {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_d80ac41c6acb8f97bef5a37ffa0a659f&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_d80ac41c6acb8f97bef5a37ffa0a659f = L.map(
#                 &quot;map_d80ac41c6acb8f97bef5a37ffa0a659f&quot;,
#                 {
#                     center: [0.0, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 1.5,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_17fe43a6f1ac7188bebfda63eb9c5063 = L.tileLayer(
#                 &quot;https://stamen-tiles-{s}.a.ssl.fastly.net/toner/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Map tiles by \u003ca target=\&quot;_blank\&quot; href=\&quot;http://stamen.com\&quot;\u003eStamen Design\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://creativecommons.org/licenses/by/3.0\&quot;\u003eCC BY 3.0\u003c/a\u003e. Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_d80ac41c6acb8f97bef5a37ffa0a659f);
#
#
#             var circle_marker_812eaafdca265438e9f5b63a6240b075 = L.circleMarker(
#                 [37.387845, -122.055197],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 1, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_d80ac41c6acb8f97bef5a37ffa0a659f);
#
#
#         var popup_232420f89fd8ecbb324241369f8be9b0 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_b00ae03e8e045de1b7333de0a426ec74 = $(`&lt;div id=&quot;html_b00ae03e8e045de1b7333de0a426ec74&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Plaxo&lt;/div&gt;`)[0];
#                 popup_232420f89fd8ecbb324241369f8be9b0.setContent(html_b00ae03e8e045de1b7333de0a426ec74);
#
#
#
#         circle_marker_812eaafdca265438e9f5b63a6240b075.bindPopup(popup_232420f89fd8ecbb324241369f8be9b0)
#         ;
#
#
#
#
#             var circle_marker_21e7cdebb378ec302582dded8af85107 = L.circleMarker(
#                 [34.017606, -118.487267],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 1, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_d80ac41c6acb8f97bef5a37ffa0a659f);
#
#
#         var popup_9696cdc7103e1db2059c43df2c2f164a = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_0920357b77f56bfa345719670c77e2d8 = $(`&lt;div id=&quot;html_0920357b77f56bfa345719670c77e2d8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Mahalo&lt;/div&gt;`)[0];
#                 popup_9696cdc7103e1db2059c43df2c2f164a.setContent(html_0920357b77f56bfa345719670c77e2d8);
#
#
#
#         circle_marker_21e7cdebb378ec302582dded8af85107.bindPopup(popup_9696cdc7103e1db2059c43df2c2f164a)
#         ;
#
#
#
#
#             var circle_marker_a2629f7761679b8d693f2047e8577e94 = L.circleMarker(
#                 [37.788482, -122.409173],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 1, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_d80ac41c6acb8f97bef5a37ffa0a659f);
#
#
#         var popup_9d3d788f8ed6afb24836aed5d3aff9b1 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_5fa570ad9561b326b3f960bf3da2ef60 = $(`&lt;div id=&quot;html_5fa570ad9561b326b3f960bf3da2ef60&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Kyte&lt;/div&gt;`)[0];
#                 popup_9d3d788f8ed6afb24836aed5d3aff9b1.setContent(html_5fa570ad9561b326b3f960bf3da2ef60);
#
#
#
#         circle_marker_a2629f7761679b8d693f2047e8577e94.bindPopup(popup_9d3d788f8ed6afb24836aed5d3aff9b1)
#         ;
#
#
#
#
#             var circle_marker_a280af0e9

# %%
print ('Compañias alrededor>=10, sb_ratio>0.45 y densidad monetaria>1.000.000$')

df=data[(data.around_companies >= 10) & (data.sb_ratio > 0.45) & (data.money_density > 1e6)]

mapa=geomap(df)

mapa
# Out:
# Compañias alrededor>=10, sb_ratio>0.45 y densidad monetaria>1.000.000$
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_cb9adbe7fa7f3caf993fd66bed39c65c {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_cb9adbe7fa7f3caf993fd66bed39c65c&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_cb9adbe7fa7f3caf993fd66bed39c65c = L.map(
#                 &quot;map_cb9adbe7fa7f3caf993fd66bed39c65c&quot;,
#                 {
#                     center: [0.0, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 1.5,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_65902bb78ee820b45fe8e0c633b84415 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_cb9adbe7fa7f3caf993fd66bed39c65c);
#
#
#             var circle_marker_59f937c7be29d62e054c5458b59fb833 = L.circleMarker(
#                 [37.446823, -122.161523],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 1, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_cb9adbe7fa7f3caf993fd66bed39c65c);
#
#
#         var popup_c311aa473914c9de30ee5d196e8f0dff = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_863cb0f7b352edb279a38db710e9f59d = $(`&lt;div id=&quot;html_863cb0f7b352edb279a38db710e9f59d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Social Gaming Network&lt;/div&gt;`)[0];
#                 popup_c311aa473914c9de30ee5d196e8f0dff.setContent(html_863cb0f7b352edb279a38db710e9f59d);
#
#
#
#         circle_marker_59f937c7be29d62e054c5458b59fb833.bindPopup(popup_c311aa473914c9de30ee5d196e8f0dff)
#         ;
#
#
#
#
#             var circle_marker_81e88fca910efe5c79a90cfb57a87f52 = L.circleMarker(
#                 [37.446382, -122.155678],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 1, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_cb9adbe7fa7f3caf993fd66bed39c65c);
#
#
#         var popup_6ecfa1e7a93c649e070b1790e5e60411 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_0095f99938d97faf3279272d5e249259 = $(`&lt;div id=&quot;html_0095f99938d97faf3279272d5e249259&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Noovo&lt;/div&gt;`)[0];
#                 popup_6ecfa1e7a93c649e070b1790e5e60411.setContent(html_0095f99938d97faf3279272d5e249259);
#
#
#
#         circle_marker_81e88fca910efe5c79a90cfb57a87f52.bindPopup(popup_6ecfa1e7a93c649e070b1790e5e60411)
#         ;
#
#
#
#
#             var circle_marker_07d55277e7305cf2092fdd37138963e3 = L.circleMarker(
#                 [37.446662, -122.164925],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 1, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_cb9adbe7fa7f3caf993fd66bed39c65c);
#
#
#         var popup_47456ae97116af563d5a8ca92c02f85e = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_3740c2b1fe93880cea2f4d42006bcebc = $(`&lt;div id=&quot;html_3740c2b1fe93880cea2f4d42006bcebc&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Weardrobe&lt;/div&gt;`)[0];
#                 popup_47456ae97116af563d5a8ca92c02f85e.setContent(html_3740c2b1fe93880cea2f4d42006bcebc);
#
#
#
#         circle_marker_07d55277e7305cf2092fdd37138963e3.bindPopup(popup_47456ae97116af563d5a8ca92c02f85e)
#         ;
#
#
#
#
#             var circle_marker_56a6a80dc24b079b300b1d65185256d0 = L.circleMarker(
#                 [37.44296, -122.151198],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fil

# %%
print ('Compañias alrededor>=10, sb_ratio>0.5 y densidad monetaria>100.000$')

df=data[(data.around_companies >= 10) & (data.sb_ratio > 0.5) & (data.money_density > 1e5)]

mapa=geomap(df)

mapa
# Out:
# Compañias alrededor>=10, sb_ratio>0.5 y densidad monetaria>100.000$
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_27d1dca2ad72df5ce149086730a2b0ce {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_27d1dca2ad72df5ce149086730a2b0ce&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_27d1dca2ad72df5ce149086730a2b0ce = L.map(
#                 &quot;map_27d1dca2ad72df5ce149086730a2b0ce&quot;,
#                 {
#                     center: [0.0, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 1.5,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_5e4b190b8c9021d8ccf1e32203460f37 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_27d1dca2ad72df5ce149086730a2b0ce);
#
#
#             var circle_marker_52334986ef3872387d13711ea31c4017 = L.circleMarker(
#                 [37.446382, -122.155678],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 1, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_27d1dca2ad72df5ce149086730a2b0ce);
#
#
#         var popup_b3d22292be79da5b509f847396c70b30 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_97b55a08678948ff3c288a5477bb77ce = $(`&lt;div id=&quot;html_97b55a08678948ff3c288a5477bb77ce&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Noovo&lt;/div&gt;`)[0];
#                 popup_b3d22292be79da5b509f847396c70b30.setContent(html_97b55a08678948ff3c288a5477bb77ce);
#
#
#
#         circle_marker_52334986ef3872387d13711ea31c4017.bindPopup(popup_b3d22292be79da5b509f847396c70b30)
#         ;
#
#
#
#
#             var circle_marker_c094022099b6bab8062d07a9781c7855 = L.circleMarker(
#                 [37.446662, -122.164925],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 1, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_27d1dca2ad72df5ce149086730a2b0ce);
#
#
#         var popup_5c982e50ac5256426584e9fd408f70af = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_48d56f2aafd213c9f67a6dd8eb2af3fa = $(`&lt;div id=&quot;html_48d56f2aafd213c9f67a6dd8eb2af3fa&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Weardrobe&lt;/div&gt;`)[0];
#                 popup_5c982e50ac5256426584e9fd408f70af.setContent(html_48d56f2aafd213c9f67a6dd8eb2af3fa);
#
#
#
#         circle_marker_c094022099b6bab8062d07a9781c7855.bindPopup(popup_5c982e50ac5256426584e9fd408f70af)
#         ;
#
#
#
#
#             var circle_marker_a6b380e3d5dc0997edd2d8526314c196 = L.circleMarker(
#                 [37.448598, -122.158497],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 1, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_27d1dca2ad72df5ce149086730a2b0ce);
#
#
#         var popup_003d39963c9651c5409e3231e17c0e7a = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_e7f2f52774eb20b5ab224b7e30a3be46 = $(`&lt;div id=&quot;html_e7f2f52774eb20b5ab224b7e30a3be46&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Bojam&lt;/div&gt;`)[0];
#                 popup_003d39963c9651c5409e3231e17c0e7a.setContent(html_e7f2f52774eb20b5ab224b7e30a3be46);
#
#
#
#         circle_marker_a6b380e3d5dc0997edd2d8526314c196.bindPopup(popup_003d39963c9651c5409e3231e17c0e7a)
#         ;
#
#
#
#
#             var circle_marker_b5af7cf64880cfe5f0812353c7852805 = L.circleMarker(
#                 [37.448598, -122.158497],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false,
