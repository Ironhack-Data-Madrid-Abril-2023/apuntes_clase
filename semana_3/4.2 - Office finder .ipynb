# %% [markdown]
# # 4.2 - Office finder mongo version
#
# #### Encontramos tu oficina

# %%
# %pip install folium
# Out:
# Requirement already satisfied: folium in /opt/homebrew/Caskroom/miniconda/base/envs/clase/lib/python3.9/site-packages (0.14.0)
# Requirement already satisfied: requests in /opt/homebrew/Caskroom/miniconda/base/envs/clase/lib/python3.9/site-packages (from folium) (2.28.1)
# Requirement already satisfied: branca>=0.6.0 in /opt/homebrew/Caskroom/miniconda/base/envs/clase/lib/python3.9/site-packages (from folium) (0.6.0)
# Requirement already satisfied: jinja2>=2.9 in /opt/homebrew/Caskroom/miniconda/base/envs/clase/lib/python3.9/site-packages (from folium) (3.1.2)
# Requirement already satisfied: numpy in /opt/homebrew/Caskroom/miniconda/base/envs/clase/lib/python3.9/site-packages (from folium) (1.23.5)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/homebrew/Caskroom/miniconda/base/envs/clase/lib/python3.9/site-packages (from jinja2>=2.9->folium) (2.1.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /opt/homebrew/Caskroom/miniconda/base/envs/clase/lib/python3.9/site-packages (from requests->folium) (1.26.13)
# Requirement already satisfied: idna<4,>=2.5 in /opt/homebrew/Caskroom/miniconda/base/envs/clase/lib/python3.9/site-packages (from requests->folium) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/homebrew/Caskroom/miniconda/base/envs/clase/lib/python3.9/site-packages (from requests->folium) (2022.12.7)
# Requirement already satisfied: charset-normalizer<3,>=2 in /opt/homebrew/Caskroom/miniconda/base/envs/clase/lib/python3.9/site-packages (from requests->folium) (2.1.1)
# WARNING: Error parsing requirements for pyarrow: [Errno 21] Is a directory: '/opt/homebrew/Caskroom/miniconda/base/envs/clase/lib/python3.9/site-packages/pyarrow-10.0.1.dist-info/METADATA'
# Note: you may need to restart the kernel to use updated packages.

# %%
# librerias

from pymongo import MongoClient

import pandas as pd

import folium   # esto es para hacer mapas

import re

# %%
# conexion a mongo

cliente=MongoClient()

db=cliente.companies

colec=db.companies

# %%
query={'$and': [
    
    {'$or': [{'category_code': 'games_video'}, 
             {'category_code': 'web'},
             {'category_code': 'ecommerce'}]},
    
    {'founded_year': {'$gte': 1999}},
    {'deadpooled_year': None},
    {'number_of_employees': {'$ne': None}},
    {'number_of_employees': {'$ne': 0}},
    {'total_money_raised': {'$ne': None}}
    
]}


filtro={'name': 1, '_id':0, 'offices.latitude': 1, 'offices.longitude': 1,
         'founded_year': 1, 'category_code':1, 'number_of_employees':1,
         'total_money_raised':1}




data=pd.json_normalize(data=colec.find(query, filtro), 
                       record_path='offices', 
                       meta=['category_code', 'name', 'number_of_employees',
                            'founded_year', 'total_money_raised'])


data.head()
# Out:
#     latitude   longitude category_code    name number_of_employees  \
# 0  34.090368 -118.393064           web    Geni                  18
# 1  37.387845 -122.055197           web   Plaxo                  50
# 2  34.017606 -118.487267           web  Mahalo                  40
# 3  37.788482 -122.409173   games_video    Kyte                  40
# 4  40.726040  -73.995722           web  Meetup                  75
#
#   founded_year total_money_raised
# 0         2006             $16.5M
# 1         2002             $28.3M
# 2         2007               $21M
# 3         2006             $23.4M
# 4         2002             $18.3M

# %%
data.insert(2, 'geo_loc', pd.Series(list(range(len(data)))))

# %%
# aqui relleno la columna con una lista de longitud y latitud
data['geo_loc']=data.apply(lambda x: [x['longitude'], x['latitude']], axis=1)


data.head()
# Out:
#     latitude   longitude                   geo_loc category_code    name  \
# 0  34.090368 -118.393064  [-118.393064, 34.090368]           web    Geni
# 1  37.387845 -122.055197  [-122.055197, 37.387845]           web   Plaxo
# 2  34.017606 -118.487267  [-118.487267, 34.017606]           web  Mahalo
# 3  37.788482 -122.409173  [-122.409173, 37.788482]   games_video    Kyte
# 4  40.726040  -73.995722    [-73.995722, 40.72604]           web  Meetup
#
#   number_of_employees founded_year total_money_raised
# 0                  18         2006             $16.5M
# 1                  50         2002             $28.3M
# 2                  40         2007               $21M
# 3                  40         2006             $23.4M
# 4                  75         2002             $18.3M

# %%
data.head()
# Out:
#     latitude   longitude                   geo_loc category_code    name  \
# 0  34.090368 -118.393064  [-118.393064, 34.090368]           web    Geni
# 1  37.387845 -122.055197  [-122.055197, 37.387845]           web   Plaxo
# 2  34.017606 -118.487267  [-118.487267, 34.017606]           web  Mahalo
# 3  37.788482 -122.409173  [-122.409173, 37.788482]   games_video    Kyte
# 4  40.726040  -73.995722    [-73.995722, 40.72604]           web  Meetup
#
#   number_of_employees founded_year total_money_raised
# 0                  18         2006             $16.5M
# 1                  50         2002             $28.3M
# 2                  40         2007               $21M
# 3                  40         2006             $23.4M
# 4                  75         2002             $18.3M

# %%
data=data.dropna()

# %%
data.tail()
# Out:
#        latitude   longitude                    geo_loc category_code  \
# 2257  29.735462  -95.413243    [-95.413243, 29.735462]   games_video
# 2258  40.756054  -73.986951    [-73.986951, 40.756054]           web
# 2260  59.617364   16.559539    [16.5595393, 59.617364]           web
# 2261  49.282455 -123.109217  [-123.109217, 49.2824551]   games_video
# 2262  38.752367   -9.146221   [-9.1462209, 38.7523672]   games_video
#
#               name number_of_employees founded_year total_money_raised
# 2257    Fictionaut                   2         2008                 $0
# 2258  Conversition                  10         2008                 $0
# 2260    Gastrogate                  12         1999                 $0
# 2261    Tiny Speck                  45         2009             $17.2M
# 2262   My TV Shows                   2         2007                 $0

# %%
def exchange(col):
    
    res=[]
    
    number=1
    
    symbol=1
    
    for e in col:
        
        if e[-1]=='k': number=1e3
        elif e[-1]=='M': number=1e6
        elif e[-1]=='B': number=1e9
            
        if e[0]=='£': symbol=1.3
        elif e[0]=='€' : symbol=1.12
        
        n_col=re.findall('[0-9.]+', e)[0]

        
        res.append(int(float(n_col) * number * symbol))
        
    return res

# %%
exchange(['$28.3M'])
# Out:
# [28300000]

# %%
data['n_total_money']=exchange(data.total_money_raised)

data.head()
# Out:
#     latitude   longitude                   geo_loc category_code    name  \
# 0  34.090368 -118.393064  [-118.393064, 34.090368]           web    Geni
# 1  37.387845 -122.055197  [-122.055197, 37.387845]           web   Plaxo
# 2  34.017606 -118.487267  [-118.487267, 34.017606]           web  Mahalo
# 3  37.788482 -122.409173  [-122.409173, 37.788482]   games_video    Kyte
# 4  40.726040  -73.995722    [-73.995722, 40.72604]           web  Meetup
#
#   number_of_employees founded_year total_money_raised  n_total_money
# 0                  18         2006             $16.5M       16500000
# 1                  50         2002             $28.3M       28300000
# 2                  40         2007               $21M       21000000
# 3                  40         2006             $23.4M       23400000
# 4                  75         2002             $18.3M       18300000

# %%
data[['latitude', 'n_total_money']].head()
# Out:
#     latitude  n_total_money
# 0  34.090368       16500000
# 1  37.387845       28300000
# 2  34.017606       21000000
# 3  37.788482       23400000
# 4  40.726040       18300000

# %%
data.reset_index(drop=True, inplace=True)

# %%
data.head()
# Out:
#     latitude   longitude                   geo_loc category_code    name  \
# 0  34.090368 -118.393064  [-118.393064, 34.090368]           web    Geni
# 1  37.387845 -122.055197  [-122.055197, 37.387845]           web   Plaxo
# 2  34.017606 -118.487267  [-118.487267, 34.017606]           web  Mahalo
# 3  37.788482 -122.409173  [-122.409173, 37.788482]   games_video    Kyte
# 4  40.726040  -73.995722    [-73.995722, 40.72604]           web  Meetup
#
#   number_of_employees founded_year total_money_raised  n_total_money
# 0                  18         2006             $16.5M       16500000
# 1                  50         2002             $28.3M       28300000
# 2                  40         2007               $21M       21000000
# 3                  40         2006             $23.4M       23400000
# 4                  75         2002             $18.3M       18300000

# %%
def classifying(date, employees):
    
    company_class=[]
    
    for i in range(len(date)):
        
        if date[i]>=2008 and employees[i]<100:
            company_class.append('StartUp')
        else:
            company_class.append('BigCorp')
            
    
    return company_class

# %%
data['company_class']=classifying(data.founded_year, data.number_of_employees)

# %%
data.tail()
# Out:
#        latitude   longitude                    geo_loc category_code  \
# 1616  29.735462  -95.413243    [-95.413243, 29.735462]   games_video
# 1617  40.756054  -73.986951    [-73.986951, 40.756054]           web
# 1618  59.617364   16.559539    [16.5595393, 59.617364]           web
# 1619  49.282455 -123.109217  [-123.109217, 49.2824551]   games_video
# 1620  38.752367   -9.146221   [-9.1462209, 38.7523672]   games_video
#
#               name number_of_employees founded_year total_money_raised  \
# 1616    Fictionaut                   2         2008                 $0
# 1617  Conversition                  10         2008                 $0
# 1618    Gastrogate                  12         1999                 $0
# 1619    Tiny Speck                  45         2009             $17.2M
# 1620   My TV Shows                   2         2007                 $0
#
#       n_total_money company_class
# 1616              0       StartUp
# 1617              0       StartUp
# 1618              0       BigCorp
# 1619       19264000       StartUp
# 1620              0       BigCorp

# %%
# insertar en mongo

#df.to_json('geoloc.json', orient='records', lines=True)

# %%
data=data.dropna()

# %%
db.geoloc.insert_many(data.to_dict('records'))

# %%
db.geoloc.create_index([('geo_loc', '2dsphere')])
# Out:
# 'geo_loc_2dsphere'

# %%
# geolocalizacion

def geoquery(df):
    
    list_money_mean=[]
    
    sb_ratio=[]
    
    n_companies=[]
    
    for i in range(len(df)):
        
        q=list(db.geoloc.find({'geo_loc': {'$near': {'$geometry': {
                                     
                                'type': 'Point',
                                'coordinates': df.geo_loc[i]},
                                
                                '$maxDistance': 1000}}}))
        
        
        long_list=len(q)
        
        # media de dinero
        money_mean=sum([q[j]['n_total_money'] for j in range(long_list)]) / long_list
        
        list_money_mean.append(money_mean)
        
        # startup-bigcorp
        
        big=sum(q[k]['company_class'].count('BigCorp') 
                if q[k]['company_class'].count('BigCorp')!=0 
                else 1 for k in range(long_list))
        
        start=sum(q[k]['company_class'].count('StartUp')  for k in range(long_list))
        
        # si sb_ratio=1 entonces big=start, si sb_ratio<1 hay más big, si sb_ratio>1 hay mas start
        sb_ratio.append(start/big)
        
        
        # nº compañias
        n_companies.append(long_list)
        
        
    df['around_companies']=n_companies
    
    df['sb_ratio']=sb_ratio
    
    df['money_density']=list_money_mean
    
    return df

# %%
data=geoquery(data)

data.head()
# Out:
#     latitude   longitude                   geo_loc category_code    name  \
# 0  34.090368 -118.393064  [-118.393064, 34.090368]           web    Geni
# 1  37.387845 -122.055197  [-122.055197, 37.387845]           web   Plaxo
# 2  34.017606 -118.487267  [-118.487267, 34.017606]           web  Mahalo
# 3  37.788482 -122.409173  [-122.409173, 37.788482]   games_video    Kyte
# 4  40.726040  -73.995722    [-73.995722, 40.72604]           web  Meetup
#
#   number_of_employees founded_year total_money_raised  n_total_money  \
# 0                  18         2006             $16.5M       16500000
# 1                  50         2002             $28.3M       28300000
# 2                  40         2007               $21M       21000000
# 3                  40         2006             $23.4M       23400000
# 4                  75         2002             $18.3M       18300000
#
#   company_class  around_companies  sb_ratio  money_density
# 0       BigCorp                 1  0.000000   1.650000e+07
# 1       BigCorp                 2  0.000000   1.415000e+07
# 2       BigCorp                 3  0.333333   8.333333e+06
# 3       BigCorp                24  0.375000   8.157333e+06
# 4       BigCorp                16  0.187500   4.370625e+06

# %%
def geomap(df, zoom_start=1.5):

    df.index=range(len(df)) 

    mapa=folium.Map(location=[0, 0],
                    tiles='openstreetmap', 
                    zoom_start=zoom_start)
    
    
    for i in range(1, len(df)):

        folium.CircleMarker([float(df.latitude[i]), float(df.longitude[i])], 
                            popup=str(df.name[i]), 
                            radius=1, 
                            icon=folium.Icon()).add_to(mapa)

    #mapa.save('images/geomap.html')
    
    return mapa

# %%
print('oficinas')

mapa=geomap(data.loc[:1500])

mapa
# Out:
# oficinas
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_175603dc9369b9880100204b78fa1dc9 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_175603dc9369b9880100204b78fa1dc9&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_175603dc9369b9880100204b78fa1dc9 = L.map(
#                 &quot;map_175603dc9369b9880100204b78fa1dc9&quot;,
#                 {
#                     center: [0.0, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 1.5,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_ceabc1b1313b73e8439a9019ac5915a4 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_175603dc9369b9880100204b78fa1dc9);
#
#
#             var circle_marker_0a05e512edc90ec25b7c14db5ba04d87 = L.circleMarker(
#                 [37.387845, -122.055197],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 1, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_175603dc9369b9880100204b78fa1dc9);
#
#
#         var popup_3bf0e9ca32b1e654473ffb75c988328d = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_6581bb9035e1148c7752811c0889dcf8 = $(`&lt;div id=&quot;html_6581bb9035e1148c7752811c0889dcf8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Plaxo&lt;/div&gt;`)[0];
#                 popup_3bf0e9ca32b1e654473ffb75c988328d.setContent(html_6581bb9035e1148c7752811c0889dcf8);
#
#
#
#         circle_marker_0a05e512edc90ec25b7c14db5ba04d87.bindPopup(popup_3bf0e9ca32b1e654473ffb75c988328d)
#         ;
#
#
#
#
#             var circle_marker_dcbe6988c560e236295a86f151d80262 = L.circleMarker(
#                 [34.017606, -118.487267],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 1, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_175603dc9369b9880100204b78fa1dc9);
#
#
#         var popup_cecbcfc50d740982e73b176c082893f7 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_729bd1b52186e1476955686e98489bb0 = $(`&lt;div id=&quot;html_729bd1b52186e1476955686e98489bb0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Mahalo&lt;/div&gt;`)[0];
#                 popup_cecbcfc50d740982e73b176c082893f7.setContent(html_729bd1b52186e1476955686e98489bb0);
#
#
#
#         circle_marker_dcbe6988c560e236295a86f151d80262.bindPopup(popup_cecbcfc50d740982e73b176c082893f7)
#         ;
#
#
#
#
#             var circle_marker_ff03dc5b095313593255a7448a5d9a4d = L.circleMarker(
#                 [37.788482, -122.409173],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 1, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_175603dc9369b9880100204b78fa1dc9);
#
#
#         var popup_d82ab3e1d475bbd467abaa053e9b072d = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_e31f7275c6c2e4463a249b799d707055 = $(`&lt;div id=&quot;html_e31f7275c6c2e4463a249b799d707055&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Kyte&lt;/div&gt;`)[0];
#                 popup_d82ab3e1d475bbd467abaa053e9b072d.setContent(html_e31f7275c6c2e4463a249b799d707055);
#
#
#
#         circle_marker_ff03dc5b095313593255a7448a5d9a4d.bindPopup(popup_d82ab3e1d475bbd467abaa053e9b072d)
#         ;
#
#
#
#
#             var circle_marker_6cfd0e8c440962b6394764605f2040df = L.circleMarker(
#                 [40.72604, -73.995722],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot

# %%
print ('Compañias alrededor>=10, sb_ratio>0.45 y densidad monetaria>1.000.000$')

df=data[(data.around_companies >= 10) & (data.sb_ratio > 0.45) & (data.money_density > 1e6)]

mapa=geomap(df)

mapa
# Out:
# Compañias alrededor>=10, sb_ratio>0.45 y densidad monetaria>1.000.000$
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_a695fafb1085101adedd08868f219324 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_a695fafb1085101adedd08868f219324&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_a695fafb1085101adedd08868f219324 = L.map(
#                 &quot;map_a695fafb1085101adedd08868f219324&quot;,
#                 {
#                     center: [0.0, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 1.5,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_c4684fac83e2f52dba84605e39d695e1 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_a695fafb1085101adedd08868f219324);
#
#
#             var circle_marker_5f06e77ad68153d1e15fa8d61766e365 = L.circleMarker(
#                 [37.446823, -122.161523],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 1, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_a695fafb1085101adedd08868f219324);
#
#
#         var popup_fd06be1eb4fd4e14c6f5db1b00eeeb28 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_7b75dd21c39bf1ea87eccbeb97e657d8 = $(`&lt;div id=&quot;html_7b75dd21c39bf1ea87eccbeb97e657d8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Social Gaming Network&lt;/div&gt;`)[0];
#                 popup_fd06be1eb4fd4e14c6f5db1b00eeeb28.setContent(html_7b75dd21c39bf1ea87eccbeb97e657d8);
#
#
#
#         circle_marker_5f06e77ad68153d1e15fa8d61766e365.bindPopup(popup_fd06be1eb4fd4e14c6f5db1b00eeeb28)
#         ;
#
#
#
#
#             var circle_marker_404f1c6217a807d33db7aceb6ff00921 = L.circleMarker(
#                 [37.446382, -122.155678],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 1, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_a695fafb1085101adedd08868f219324);
#
#
#         var popup_4a4447ab45fec12033838acf984f5ac1 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_42170fce9cc9f67ab7e0ec5d89ccc4c5 = $(`&lt;div id=&quot;html_42170fce9cc9f67ab7e0ec5d89ccc4c5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Noovo&lt;/div&gt;`)[0];
#                 popup_4a4447ab45fec12033838acf984f5ac1.setContent(html_42170fce9cc9f67ab7e0ec5d89ccc4c5);
#
#
#
#         circle_marker_404f1c6217a807d33db7aceb6ff00921.bindPopup(popup_4a4447ab45fec12033838acf984f5ac1)
#         ;
#
#
#
#
#             var circle_marker_0c86528c4bbcd93c1aec0c30b898f08d = L.circleMarker(
#                 [37.446662, -122.164925],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 1, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_a695fafb1085101adedd08868f219324);
#
#
#         var popup_ad15a10330826a6a776d604ba82e2dfe = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_4d45b41f535db34eeed87da1debb52eb = $(`&lt;div id=&quot;html_4d45b41f535db34eeed87da1debb52eb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Weardrobe&lt;/div&gt;`)[0];
#                 popup_ad15a10330826a6a776d604ba82e2dfe.setContent(html_4d45b41f535db34eeed87da1debb52eb);
#
#
#
#         circle_marker_0c86528c4bbcd93c1aec0c30b898f08d.bindPopup(popup_ad15a10330826a6a776d604ba82e2dfe)
#         ;
#
#
#
#
#             var circle_marker_fbdf4c558e224754d3bdf3580c30bd4e = L.circleMarker(
#                 [37.44296, -122.151198],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fil

# %%
print ('Compañias alrededor>=10, sb_ratio>0.5 y densidad monetaria>100.000$')

df=data[(data.around_companies >= 10) & (data.sb_ratio > 0.5) & (data.money_density > 1e5)]

mapa=geomap(df)

mapa
# Out:
# Compañias alrededor>=10, sb_ratio>0.5 y densidad monetaria>100.000$
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_d006c6321637cb71c773b35ea4ecd6ae {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_d006c6321637cb71c773b35ea4ecd6ae&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_d006c6321637cb71c773b35ea4ecd6ae = L.map(
#                 &quot;map_d006c6321637cb71c773b35ea4ecd6ae&quot;,
#                 {
#                     center: [0.0, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 1.5,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_ef5603ba8b951d9abae8ddad338fae64 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_d006c6321637cb71c773b35ea4ecd6ae);
#
#
#             var circle_marker_5465634129e66b68833b0a9d8ac54ac7 = L.circleMarker(
#                 [37.446382, -122.155678],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 1, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_d006c6321637cb71c773b35ea4ecd6ae);
#
#
#         var popup_6ebbb9b858d7ee7c950bb39d9bb90102 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_11b62063d3053665e704f25630f763d4 = $(`&lt;div id=&quot;html_11b62063d3053665e704f25630f763d4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Noovo&lt;/div&gt;`)[0];
#                 popup_6ebbb9b858d7ee7c950bb39d9bb90102.setContent(html_11b62063d3053665e704f25630f763d4);
#
#
#
#         circle_marker_5465634129e66b68833b0a9d8ac54ac7.bindPopup(popup_6ebbb9b858d7ee7c950bb39d9bb90102)
#         ;
#
#
#
#
#             var circle_marker_15756e292833622b7b6ddefb9d2b958e = L.circleMarker(
#                 [37.446662, -122.164925],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 1, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_d006c6321637cb71c773b35ea4ecd6ae);
#
#
#         var popup_7ade666c1937172ff98a5624cac7b560 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_53b45e1f7c1638eeff65e7a1fcda6a44 = $(`&lt;div id=&quot;html_53b45e1f7c1638eeff65e7a1fcda6a44&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Weardrobe&lt;/div&gt;`)[0];
#                 popup_7ade666c1937172ff98a5624cac7b560.setContent(html_53b45e1f7c1638eeff65e7a1fcda6a44);
#
#
#
#         circle_marker_15756e292833622b7b6ddefb9d2b958e.bindPopup(popup_7ade666c1937172ff98a5624cac7b560)
#         ;
#
#
#
#
#             var circle_marker_655bcb16cf6dd649859d827b57cce0ff = L.circleMarker(
#                 [37.448598, -122.158497],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 1, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_d006c6321637cb71c773b35ea4ecd6ae);
#
#
#         var popup_3ec8f9c5eb496055d5c51a20a60ddad7 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_6a8a13314a70928dd9daf96831b5b1aa = $(`&lt;div id=&quot;html_6a8a13314a70928dd9daf96831b5b1aa&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Bojam&lt;/div&gt;`)[0];
#                 popup_3ec8f9c5eb496055d5c51a20a60ddad7.setContent(html_6a8a13314a70928dd9daf96831b5b1aa);
#
#
#
#         circle_marker_655bcb16cf6dd649859d827b57cce0ff.bindPopup(popup_3ec8f9c5eb496055d5c51a20a60ddad7)
#         ;
#
#
#
#
#             var circle_marker_82d329705e5602084918be3d254a4ef3 = L.circleMarker(
#                 [37.448598, -122.158497],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false,
